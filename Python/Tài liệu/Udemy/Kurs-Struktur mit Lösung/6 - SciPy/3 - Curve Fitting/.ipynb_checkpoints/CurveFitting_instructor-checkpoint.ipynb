# %% [markdown]
# ## Optimierung mithilfe von Curve fitting
#
# Curve fitting ist ein Verfahren zum Auffinden der am besten passenden Kurve für einen gegebenen Punkte-Set durch Minimieren der Summe der Quadrate der Offsets ("Residuals") der Punkte aus der Kurve.
#
# <img src="images/curve_fitting_1.png" alt="Curve Fitting 1" style="width: 150px;"/>
# <img src="images/curve_fitting_2.png" alt="Curve Fitting 2" style="width: 150px;"/>
# <img src="images/curve_fitting_3.png" alt="Curve Fitting 3" style="width: 150px;"/>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
def f(x):
    return x**2 + 10*np.sin(x)

# %%
x = np.linspace(-10, 10, 51)
x
# Out:
# array([-10. ,  -9.6,  -9.2,  -8.8,  -8.4,  -8. ,  -7.6,  -7.2,  -6.8,
#         -6.4,  -6. ,  -5.6,  -5.2,  -4.8,  -4.4,  -4. ,  -3.6,  -3.2,
#         -2.8,  -2.4,  -2. ,  -1.6,  -1.2,  -0.8,  -0.4,   0. ,   0.4,
#          0.8,   1.2,   1.6,   2. ,   2.4,   2.8,   3.2,   3.6,   4. ,
#          4.4,   4.8,   5.2,   5.6,   6. ,   6.4,   6.8,   7.2,   7.6,
#          8. ,   8.4,   8.8,   9.2,   9.6,  10. ])

# %%
y = f(x)
y
# Out:
# array([105.44021111,  93.90326781,  82.41110086,  71.59082807,
#         62.01401092,  54.10641753,  48.08080328,  43.90332136,
#         41.29886649,  39.79450795,  38.79415498,  37.67266638,
#         35.87454656,  33.00164609,  28.87602074,  23.56802495,
#         17.38520443,  10.82374143,   4.4901185 ,  -0.99463181,
#         -5.09297427,  -7.43573603,  -7.88039086,  -6.53356091,
#         -3.73418342,   0.        ,   4.05418342,   7.81356091,
#         10.76039086,  12.55573603,  13.09297427,  12.51463181,
#         11.1898815 ,   9.65625857,   8.53479557,   8.43197505,
#          9.84397926,  13.07835391,  18.20545344,  25.04733362,
#         33.20584502,  42.12549205,  51.18113351,  59.77667864,
#         67.43919672,  73.89358247,  79.10598908,  83.28917193,
#         86.86889914,  90.41673219,  94.55978889])

# %%
fig = plt.figure(figsize=(5, 4), dpi=160)
plt.plot(x, y, 'g-')
plt.grid()
plt.show()

# %%
y_noise = f(x) + 5 * np.random.randn(x.size)
y_noise
# Out:
# array([100.5237241 ,  97.66752375,  80.58260741,  73.62236537,
#         58.6153489 ,  62.86484796,  53.78890995,  42.69133961,
#         39.02669244,  46.25701015,  33.91042328,  35.33551208,
#         43.77993935,  26.36139824,  29.65770075,  27.03639888,
#         19.41692001,   9.48303964,   9.6987477 ,   3.29794457,
#        -10.89850441,  -9.18721707, -11.79005158,  -4.12543872,
#          3.39051372,   7.16186569,   5.29075126,   9.1080185 ,
#         10.43671875,   9.05346449,  20.46858921,  12.74375654,
#          6.53299379,   6.9305323 ,   7.81744355,   4.05982073,
#          5.80426161,   4.98087462,  13.48178598,  20.58870353,
#         33.74402217,  38.70482712,  47.96743618,  64.25334712,
#         66.11733216,  67.60748512,  78.53079095,  86.73735993,
#         85.95789455,  92.59051329,  92.30938895])

# %%
fig = plt.figure(figsize=(5, 4), dpi=160)
plt.plot(x, y, 'g-')
plt.plot(x, y_noise, 'r.')
plt.grid()
plt.show()

# %% [markdown]
# - Approximiere die Funktion $f_2(x)=ax^2+b\sin(x)$ indem wir die optimalen Werte für `a` and `b` ermitteln.

# %%
def f2(x, a, b):
    return a * x ** 2 + b * np.sin(x)

# %%
import scipy.optimize as opt

# %%
guess = [2,2] # start werte für a und b
params, cov = opt.curve_fit(f2, x, y_noise, guess)
params
# Out:
# array([ 0.99537469, 10.50257553])

# %%
a = params[0]
b = params[1]
y_fit = f2(x, a, b)
y_fit
# Out:
# array([105.25109169,  93.56461151,  81.90759551,  70.93867891,
#         61.25814846,  53.31317037,  47.32719256,  43.26466718,
#         40.83666282,  39.54648043,  38.76807117,  37.84487579,
#         36.19348084,  33.39572688,  29.26472663,  23.87437039,
#         17.54766035,  10.80571566,   4.28549921,  -1.36074486,
#         -5.56846615,  -7.94993806,  -8.35547135,  -6.89704673,
#         -3.9306356 ,   0.        ,   4.2491555 ,   8.17112633,
#         11.22215045,  13.04625647,  13.53146366,  12.82746128,
#         11.32197591,   9.57955796,   8.25245159,   7.97761965,
#          9.27618132,  12.47113879,  17.63638234,  24.5850247 ,
#         32.89890642,  41.99461408,  51.2155884 ,  59.93578056,
#         67.65849149,  74.0947898 ,  79.20912763,  83.2249529 ,
#         86.58943182,  89.90285114,  93.82384608])

# %%
fig = plt.figure(figsize=(5, 4), dpi=160)
plt.plot(x, y, 'g-')
plt.plot(x, y_noise, 'r.')
plt.plot(x, y_fit, 'b+')
plt.grid()
plt.show()
