# %% [markdown]
# ## Daten visualisieren mit Punktdiagramme (X,Y)

# %%
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

# %%
X = pd.read_csv('autos_stripped.csv', header=0, index_col=0, encoding='ISO-8859-1')
X.head()
# Out:
#    seller  price vehicleType  yearOfRegistration    gearbox  powerPS  model  \
# 0  privat    480         NaN                1993    manuell        0   golf
# 1  privat  18300       coupe                2011    manuell      190    NaN
# 2  privat   9800         suv                2004  automatik      163  grand
# 3  privat   1500  kleinwagen                2001    manuell       75   golf
# 4  privat   3600  kleinwagen                2008    manuell       69  fabia
#
#    kilometer fuelType       brand          dateCreated  postalCode
# 0     150000   benzin  volkswagen  2016-03-24 00:00:00       70435
# 1     125000   diesel        audi  2016-03-24 00:00:00       66954
# 2     125000   diesel        jeep  2016-03-14 00:00:00       90480
# 3     150000   benzin  volkswagen  2016-03-17 00:00:00       91074
# 4      90000   diesel       skoda  2016-03-31 00:00:00       60437

# %%
number_ps = X.powerPS.value_counts().sort_index()
number_ps
# Out:
# 0        40820
# 1           34
# 2           10
# 3            9
# 4           30
# 5          103
# 6           11
# 7           11
# 8            7
# 9            5
# 10          17
# 11          28
# 12          24
# 13           8
# 14          21
# 15          21
# 16          11
# 17           8
# 18          54
# 19          15
# 20          23
# 21           6
# 22           5
# 23          45
# 24          31
# 25          16
# 26         291
# 27          40
# 28           6
# 29          35
#          ...
# 11509        1
# 11530        1
# 11620        1
# 11635        1
# 12012        1
# 12510        2
# 12512        3
# 12684        1
# 13616        1
# 13636        1
# 14009        1
# 15001        1
# 15016        1
# 15017        1
# 15020        1
# 15033        1
# 16011        1
# 16051        1
# 16311        1
# 16312        1
# 17011        1
# 17019        1
# 17322        1
# 17410        1
# 17700        1
# 17932        1
# 19208        1
# 19211        1
# 19312        1
# 20000        1
# Name: powerPS, Length: 794, dtype: int64

# %%
number_ps = number_ps[ (number_ps > 100) & (number_ps < 1500) ]
number_ps
# Out:
# 5       103
# 26      291
# 34      191
# 39      145
# 40      323
# 41      442
# 43      115
# 44      407
# 52      321
# 53      209
# 56      274
# 57      134
# 59      248
# 61      989
# 63      404
# 66      189
# 67      441
# 70     1090
# 71     1448
# 72      492
# 73      767
# 74      375
# 76      255
# 77      898
# 78      211
# 79      143
# 81      126
# 83      373
# 84      962
# 85      599
#        ...
# 272     920
# 275     113
# 279     212
# 280     326
# 286     809
# 292     111
# 299     273
# 300     420
# 305     122
# 306    1131
# 310     147
# 313     271
# 320     284
# 325     113
# 326     234
# 333     276
# 340     354
# 344     114
# 349     112
# 354     117
# 355     114
# 360     113
# 367     112
# 385     105
# 387     191
# 400     149
# 408     112
# 420     164
# 450     139
# 500     123
# Name: powerPS, Length: 136, dtype: int64

# %%
x = number_ps.index
y = number_ps.values

# %%
area = y
colors = (30 * y) ** 2
area
# Out:
# array([ 103,  291,  191,  145,  323,  442,  115,  407,  321,  209,  274,
#         134,  248,  989,  404,  189,  441, 1090, 1448,  492,  767,  375,
#         255,  898,  211,  143,  126,  373,  962,  599,  786,  106,  117,
#         446,  390,  134,  535, 1032,  610,  988,  141,  433, 1365,  169,
#         551,  194,  939,  949,  215, 1250,  373,  225,  532,  415, 1495,
#         921,  454,  657,  865,  288,  726,  694, 1021,  150, 1197,  233,
#         106,  977,  974,  206,  931,  248,  105,  121,  121,  210, 1399,
#         397,  102,  806,  109,  644,  188, 1191,  118,  199,  222,  190,
#        1292,  806,  138,  184,  500,  736,  814,  108, 1051,  148,  335,
#        1134,  939,  193,  453,  259,  723,  107,  920,  113,  212,  326,
#         809,  111,  273,  420,  122, 1131,  147,  271,  284,  113,  234,
#         276,  354,  114,  112,  117,  114,  113,  112,  105,  191,  149,
#         112,  164,  139,  123], dtype=int64)

# %%
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.xlabel("PS")
plt.ylabel("#Fahrzeuge")
plt.show()
