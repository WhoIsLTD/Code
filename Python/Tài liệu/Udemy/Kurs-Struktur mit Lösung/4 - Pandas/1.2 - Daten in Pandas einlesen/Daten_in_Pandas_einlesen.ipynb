# %% [markdown]
# ## Daten einlesen
#
# Wir haben Daten in einer CSV Datei über Autos die in Ebay verkauft wurden. In den folgenden Lektionen werden wir mit folgendem Dataset arbeiten und weiter untersuchen!
#
# Folgende Daten sind enthalten:
#
#
# - dateCrawled : when this ad was first crawled, all field-values are taken from this date
# - name : "name" of the car
# - seller : private or dealer
# - offerType
# - price : the price on the ad to sell the car
# - abtest
# - vehicleType
# - yearOfRegistration : at which year the car was first registered
# - gearbox
# - powerPS : power of the car in PS
# - model
# - kilometer : how many kilometers the car has driven
# - monthOfRegistration : at which month the car was first registered
# - fuelType
# - brand
# - notRepairedDamage : if the car has a damage which is not repaired yet
# - dateCreated : the date for which the ad at ebay was created
# - nrOfPictures : number of pictures in the ad
# - postalCode
# - lastSeenOnline : when the crawler saw this ad last online

# %%
import numpy as np

# %%
X = []

# %%
f = open('autos_full.csv', encoding='ISO-8859-1')
lines = f.readlines()[1:]

for line in lines:
    values = line.split(',')
    X.append(values)

X
# Out:
# [['2016-03-24 11:52:17',
#   'Golf_3_1.6',
#   'privat',
#   'Angebot',
#   '480',
#   'test',
#   '',
#   '1993',
#   'manuell',
#   '0',
#   'golf',
#   '150000',
#   '0',
#   'benzin',
#   'volkswagen',
#   '',
#   '2016-03-24 00:00:00',
#   '0',
#   '70435',
#   '2016-04-07 03:16:57\n'],
#  ['2016-03-24 10:58:45',
#   'A5_Sportback_2.7_Tdi',
#   'privat',
#   'Angebot',
#   '18300',
#   'test',
#   'coupe',
#   '2011',
#   'manuell',
#   '190',
#   '',
#   '125000',
#   '5',
#   'diesel',
#   'audi',
#   'ja',
#   '2016-03-24 00:00:00',
#   '0',
#   '66954',
#   '2016-04-07 01:46:50\n'],
#  ['2016-03-14 12:52:21',
#   'Jeep_Grand_Cherokee_"Overland"',
#   'privat',
#   'Angebot',
#   '9800',
#   'test',
#   'suv',
#   '2004',
#   'automatik',
#   '163',
#   'grand',
#   '125000',
#   '8',
#   'diesel',
#   'jeep',
#   '',
#   '2016-03-14 00:00:00',
#   '0',
#   '90480',
#   '2016-04-05 12:47:46\n'],
#  ['2016-03-17 16:54:04',
#   'GOLF_4_1_4__3TÜRER',
#   'privat',
#   'Angebot',
#   '1500',
#   'test',
#   'kleinwagen',
#   '2001',
#   'manuell',
#   '75',
#   'golf',
#   '150000',
#   '6',
#   'benzin',
#   'volkswagen',
#   'nein',
#   '2016-03-17 00:00:00',
#   '0',
#   '91074',
#   '2016-03-17 17:40:17\n'],
#  ['2016-03-31 17:25:20',
#   'Skoda_Fabia_1.4_TDI_PD_Classic',
#   'privat',
#   'Angebot',
#   '3600',
#   'test',
#   'kleinwagen',
#   '2008',
#   'manuell',
#   '69',
#   'fabia',
#   '90000',
#   '7',
#   'diesel',
#   'skoda',
#   'nein',
#   '2016-03-31 00:00:00',
#   '0',
#   '60437',
#   '2016-04-06 10:17:21\n'],
#  ['2016-04-04 17:36:23',
#   'BMW_316i___e36_Limousine___Bastlerfahrzeug__Export',
#   'privat',
#   'Angebot',
#   '650',
#   'test',
#   'limousine',
#   '1995',
#   'manuell',
#   '102',
#   '3er',
#   '150000',
#   '10',
#   'benzin',
#   'bmw',
#   'ja',
#   '2016-04-04 00:00:00',
#   '0',
#   '33775',
#   '2016-04-06 19:17:07\n'],
#  ['2016-04-01 20:48:51',
#   'Peugeot_206_CC_110_Platinum',
#   'privat',
#   'Angebot',
#   '2200',
#   'test',
#   'cabrio',
#   '2004',
#   'manuell',
#   '109',
#   '2_reihe',
#   '150000',
#   '8',
#   'benzin',
#   'peugeot',
#   'nein',
#   '2016-04-01 00:00:00',
#   '0',
#   '67112',
#   '2016-04-05 18:18:39\n'],
#  ['2016-03-21 18:54:38',
#   'VW_Derby_Bj_80__Scheunenfund',
#   'privat',
#   'Angebot',
#   '0',
#   'test',
#   'limousine',
#   '1980',
#   'manuell',
#   '50',
#   'andere',
#   '40000',
#   '7',
#   'benzin',
#   'volkswagen',
#   'nein',
#   '2016-03-21 00:00:00',
#   '0',
#   '19348',
#   '2016-03-25 16:47:58\n'],
#  ['2016-04-04 23:42:13',
#   'Ford_C___Max_Titanium_1_0_L_EcoBoost',
#   'privat',
#   'Angebot',
#   '14500',
#   'control',
#   'bus',
#   '2014',
#   'manuell',
#   '125',
#   'c_max',
#   '30000',
#   '8',
#   'benzin',
#   'ford',
#   '',
#   '2016-04-04 00:00:00',
#   '0',
#   '94505',
#   '2016-04-04 23:42:13\n'],
#  ['2016-03-17 10:53:50',
#   'VW_Golf_4_5_tuerig_zu_verkaufen_mit_Anhaengerkupplung',
#   'privat',
#   'Angebot',
#   '999',
#   'test',
#   'kleinwagen',
#   '1998',
#   'manuell',
#   '101',
#   'golf',
#   '150000',
#   '0',
#   '',
#   'volkswagen',
#   '',
#   '2016-03-17 00:00:00',
#   '0',
#   '27472',
#   '2016-03-31 17:17:06\n'],
#  ['2016-03-26 19:54:18',
#   'Mazda_3_1.6_Sport',
#   'privat',
#   'Angebot',
#   '2000',
#   'control',
#   'limousine',
#   '2004',
#   'manuell',
#   '105',
#   '3_reihe',
#   '150000',
#   '12',
#   'benzin',
#   'mazda',
#   'nein',
#   '2016-03-26 00:00:00',
#   '0',
#   '96224',
#   '2016-04-06 10:45:34\n'],
#  ['2016-04-07 10:06:22',
#   'Volkswagen_Passat_Variant_2.0_TDI_Comfortline',
#   'privat',
#   'Angebot',
#   '2799',
#   'control',
#   'kombi',
#   '2005',
#   'manuell',
#   '140',
#   'passat',
#   '150000',
#   '12',
#   'diesel',
#   'volkswagen',
#   'ja',
#   '2016-04-07 00:00:00',
#   '0',
#   '57290',
#   '2016-04-07 10:25:17\n'],
#  ['2016-03-15 22:49:09',
#   'VW_Passat_Facelift_35i__"7Sitzer"',
#   'privat',
#   'Angebot',
#   '999',
#   'control',
#   'kombi',
#   '1995',
#   'manuell',
#   '115',
#   'passat',
#   '150000',
#   '11',
#   'benzin',
#   'volkswagen',
#   '',
#   '2016-03-15 00:00:00',
#   '0',
#   '37269',
#   '2016-04-01 13:16:16\n'],
#  ['2016-03-21 21:37:40',
#   'VW_PASSAT_1.9_TDI_131_PS_LEDER',
#   'privat',
#   'Angebot',
#   '2500',
#   'control',
#   'kombi',
#   '2004',
#   'manuell',
#   '131',
#   'passat',
#   '150000',
#   '2',
#   '',
#   'volkswagen',
#   'nein',
#   '2016-03-21 00:00:00',
#   '0',
#   '90762',
#   '2016-03-23 02:50:54\n'],
#  ['2016-03-21 12:57:01',
#   'Nissan_Navara_2.5DPF_SE4x4_Klima_Sitzheizg_Bluetooth.Doppelkabine',
#   'privat',
#   'Angebot',
#   '17999',
#   'control',
#   'suv',
#   '2011',
#   'manuell',
#   '190',
#   'navara',
#   '70000',
#   '3',
#   'diesel',
#   'nissan',
#   'nein',
#   '2016-03-21 00:00:00',
#   '0',
#   '04177',
#   '2016-04-06 07:45:42\n'],
#  ['2016-03-11 21:39:15',
#   'KA_Lufthansa_Edition_450\x80_VB',
#   'privat',
#   'Angebot',
#   '450',
#   'test',
#   'kleinwagen',
#   '1910',
#   '',
#   '0',
#   'ka',
#   '5000',
#   '0',
#   'benzin',
#   'ford',
#   '',
#   '2016-03-11 00:00:00',
#   '0',
#   '24148',
#   '2016-03-19 08:46:47\n'],
#  ['2016-04-01 12:46:46',
#   'Polo_6n_1_4',
#   'privat',
#   'Angebot',
#   '300',
#   'test',
#   '',
#   '2016',
#   '',
#   '60',
#   'polo',
#   '150000',
#   '0',
#   'benzin',
#   'volkswagen',
#   '',
#   '2016-04-01 00:00:00',
#   '0',
#   '38871',
#   '2016-04-01 12:46:46\n'],
#  ['2016-03-20 10:25:19',
#   'Renault_Twingo_1.2_16V_Aut.',
#   'privat',
#   'Angebot',
#   '1750',
#   'control',
#   'kleinwagen',
#   '2004',
#   'automatik',
#   '75',
#   'twingo',
#   '150000',
#   '2',
#   'benzin',
#   'renault',
#   'nein',
#   '2016-03-20 00:00:00',
#   '0',
#   '65599',
#   '2016-04-06 13:16:07\n'],
#  ['2016-03-23 15:48:05',
#   'Ford_C_MAX_2.0_TDCi_DPF_Titanium',
#   'privat',
#   'Angebot',
#   '7550',
#   'test',
#   'bus',
#   '2007',
#   'manuell',
#   '136',
#   'c_max',
#   '150000',
#   '6',
#   'diesel',
#   'ford',
#   'nein',
#   '2016-03-23 00:00:00',
#   '0',
#   '88361',
#   '2016-04-05 18:45:11\n'],
#  ['2016-04-01 22:55:47',
#   'Mercedes_Benz_A_160_Classic_Klima',
#   'privat',
#   'Angebot',
#   '1850',
#   'test',
#   'bus',
#   '2004',
#   'manuell',
#   '102',
#   'a_klasse',
#   '150000',
#   '1',
#   'benzin',
#   'mercedes_benz',
#   'nein',
#   '2016-04-01 00:00:00',
#   '0',
#   '49565',
#   '2016-04-05 22:46:05\n'],
#  ['2016-04-01 19:56:48',
#   'Volkswagen_Scirocco_1.4_TSI_Sport',
#   'privat',
#   'Angebot',
#   '10400',
#   'control',
#   'coupe',
#   '2009',
#   'manuell',
#   '160',
#   'scirocco',
#   '100000',
#   '4',
#   'benzin',
#   'volkswagen',
#   'nein',
#   '2016-04-01 00:00:00',
#   '0',
#   '75365',
#   '2016-04-05 16:45:49\n'],
#  ['2016-03-27 11:38:00',
#   'BMW_530i_TÜV_7/17_Scheckheftgepflegt_sehr_guter_Zustand',
#   'privat',
#   'Angebot',
#   '3699',
#   'test',
#   'limousine',
#   '2002',
#   'automatik',
#   '231',
#   '5er',
#   '150000',
#   '7',
#   'benzin',
#   'bmw',
#   'nein',
#   '2016-03-27 00:00:00',
#   '0',
#   '68309',
#   '2016-04-07 06:44:26\n'],
#  ['2016-03-23 14:52:51',
#   'Opel_Meriva_1.Hand_TÜV_3.2018',
#   'privat',
#   'Angebot',
#   '2900',
#   'test',
#   '',
#   '2018',
#   'manuell',
#   '90',
#   'meriva',
#   '150000',
#   '5',
#   'benzin',
#   'opel',
#   'nein',
#   '2016-03-23 00:00:00',
#   '0',
#   '49716',
#   '2016-03-31 01:16:33\n'],
#  ['2016-03-12 19:43:07',
#   'Stadtflitzer',
#   'privat',
#   'Angebot',
#   '450',
#   'test',
#   'kleinwagen',
#   '1997',
#   'manuell',
#   '50',
#   'arosa',
#   '150000',
#   '5',
#   'benzin',
#   'seat',
#   'nein',
#   '2016-03-12 00:00:00',
#   '0',
#   '09526',
#   '2016-03-21 01:46:11\n'],
#  ['2016-03-13 20:40:49',
#   'MERCEDES_200E__TÜV_04/2016',
#   'privat',
#   'Angebot',
#   '500',
#   'test',
#   'limousine',
#   '1990',
#   'manuell',
#   '118',
#   'andere',
#   '150000',
#   '10',
#   'benzin',
#   'mercedes_benz',
#   'ja',
#   '2016-03-13 00:00:00',
#   '0',
#   '35390',
#   '2016-03-13 20:40:49\n'],
#  ['2016-03-18 21:44:09',
#   'BMW_530d_touring_Vollausstattung_NAVI',
#   'privat',
#   'Angebot',
#   '2500',
#   'control',
#   'kombi',
#   '2002',
#   'automatik',
#   '193',
#   '5er',
#   '150000',
#   '9',
#   'diesel',
#   'bmw',
#   'ja',
#   '2016-03-18 00:00:00',
#   '0',
#   '73765',
#   '2016-03-18 21:44:09\n'],
#  ['2016-03-10 19:38:18',
#   'Citroen_C4_Grand_Picasso.',
#   'privat',
#   'Angebot',
#   '5555',
#   'control',
#   '',
#   '2017',
#   'manuell',
#   '125',
#   'c4',
#   '125000',
#   '4',
#   '',
#   'citroen',
#   'nein',
#   '2016-03-10 00:00:00',
#   '0',
#   '31139',
#   '2016-03-16 09:16:46\n'],
#  ['2016-03-07 12:51:23',
#   'Honda_Civic_1.4_i_VTEC_Comfort',
#   'privat',
#   'Angebot',
#   '6900',
#   'test',
#   'limousine',
#   '2008',
#   'manuell',
#   '99',
#   'civic',
#   '60000',
#   '11',
#   'benzin',
#   'honda',
#   'nein',
#   '2016-03-07 00:00:00',
#   '0',
#   '12621',
#   '2016-03-26 09:44:53\n'],
#  ['2016-03-09 11:56:38',
#   'Volkswagen_T3_andere',
#   'privat',
#   'Angebot',
#   '1990',
#   'test',
#   'bus',
#   '1981',
#   'manuell',
#   '50',
#   'transporter',
#   '5000',
#   '1',
#   'benzin',
#   'volkswagen',
#   'nein',
#   '2016-03-09 00:00:00',
#   '0',
#   '87471',
#   '2016-03-10 07:44:33\n'],
#  ['2016-03-08 19:55:19',
#   'Fiat_Punto_1.2',
#   'privat',
#   'Angebot',
#   '690',
#   'test',
#   'kleinwagen',
#   '2003',
#   'manuell',
#   '60',
#   'punto',
#   '150000',
#   '3',
#   'benzin',
#   'fiat',
#   'nein',
#   '2016-03-08 00:00:00',
#   '0',
#   '86199',
#   '2016-03-09 11:45:28\n'],
#  ['2016-04-03 15:48:11',
#   'Mercedes_Benz_E_250_D_Original_Zustand_!!',
#   'privat',
#   'Angebot',
#   '3300',
#   'test',
#   'limousine',
#   '1995',
#   'automatik',
#   '113',
#   'e_klasse',
#   '150000',
#   '1',
#   'diesel',
#   'mercedes_benz',
#   'nein',
#   '2016-04-03 00:00:00',
#   '0',
#   '53879',
#   '2016-04-05 15:16:05\n'],
#  ['2016-03-29 16:57:02',
#   'Renault_clio_1.2_TÜV_07/2016',
#   'privat',
#   'Angebot',
#   '899',
#   'control',
#   '',
#   '2016',
#   'manuell',
#   '60',
#   'clio',
#   '150000',
#   '6',
#   'benzin',
#   'renault',
#   '',
#   '2016-03-29 00:00:00',
#   '0',
#   '37075',
#   '2016-03-29 17:43:07\n'],
#  ['2016-03-15 20:59:01',
#   'Golf_3_....._1.4',
#   'privat',
#   'Angebot',
#   '245',
#   'test',
#   'limousine',
#   '1994',
#   '',
#   '0',
#   'golf',
#   '150000',
#   '2',
#   'benzin',
#   'volkswagen',
#   'nein',
#   '2016-03-15 00:00:00',
#   '0',
#   '44145',
#   '2016-03-17 18:17:43\n'],
#  ['2016-03-25 21:48:47',
#   'BMW_325i_Aut.',
#   'privat',
#   'Angebot',
#   '18000',
#   'test',
#   'limousine',
#   '2007',
#   'automatik',
#   '218',
#   '3er',
#   '20000',
#   '5',
#   'benzin',
#   'bmw',
#   'nein',
#   '2016-03-25 00:00:00',
#   '0',
#   '39179',
#   '2016-04-07 04:45:21\n'],
#  ['2016-03-17 18:55:12',
#   'Mercedes_Benz_E_200_CDI_Automatik_Classic',
#   'privat',
#   'Angebot',
#   '3500',
#   'control',
#   'limousine',
#   '2004',
#   'automatik',
#   '122',
#   'e_klasse',
#   '150000',
#   '11',
#   'diesel',
#   'mercedes_benz',
#   'nein',
#   '2016-03-17 00:00:00',
#   '0',
#   '67071',
#   '2016-03-30 15:46:10\n'],
#  ['2016-03-08 07:54:46',
#   'VW_Golf_3',
#   'privat',
#   'Angebot',
#   '350',
#   'test',
#   '',
#   '2016',
#   'manuell',
#   '75',
#   'golf',
#   '150000',
#   '4',
#   'benzin',
#   'volkswagen',
#   'nein',
#   '2016-03-08 00:00:00',
#   '0',
#   '19386',
#   '2016-03-08 09:44:50\n'],
#  ['2016-03-11 11:50:37',
#   'Opel_Kadett_E_CC',
#   'privat',
#   'Angebot',
#   '1600',
#   'control',
#   'andere',
#   '1991',
#   'manuell',
#   '75',
#   'kadett',
#   '70000',
#   '0',
#   '',
#   'opel',
#   '',
#   '2016-03-11 00:00:00',
#   '0',
#   '02943',
#   '2016-04-07 03:46:09\n'],
#  ['2016-03-28 17:50:15',
#   'Renault_Kangoo_1.9_Diesel',
#   'privat',
#   'Angebot',
#   '1500',
#   'test',
#   '',
#   '2016',
#   '',
#   '0',
#   'kangoo',
#   '150000',
#   '1',
#   'diesel',
#   'renault',
#   'nein',
#   '2016-03-28 00:00:00',
#   '0',
#   '46483',
#   '2016-03-30 09:18:02\n'],
#  ['2016-04-01 17:45:07',
#   'Abschleppwagen_Vw_LT_195.000_gruene_Plakette_TÜV_8/2017',
#   'privat',
#   'Angebot',
#   '11900',
#   'test',
#   'andere',
#   '2002',
#   'manuell',
#   '129',
#   'andere',
#   '150000',
#   '11',
#   'diesel',
#   'volkswagen',
#   'nein',
#   '2016-04-01 00:00:00',
#   '0',
#   '10551',
#   '2016-04-05 12:47:30\n'],
#  ['2016-03-25 15:50:30',
#   'Mercedes_Camper_D407',
#   'privat',
#   'Angebot',
#   '1500',
#   'test',
#   'bus',
#   '1984',
#   'manuell',
#   '70',
#   'andere',
#   '150000',
#   '8',
#   'diesel',
#   'mercedes_benz',
#   'nein',
#   '2016-03-25 00:00:00',
#   '0',
#   '22767',
#   '2016-03-27 03:17:02\n'],
#  ['2016-03-26 22:06:17',
#   'Suche_Opel_corsa_a_zu_verschenken',
#   'privat',
#   'Angebot',
#   '0',
#   'test',
#   '',
#   '1990',
#   '',
#   '0',
#   'corsa',
#   '150000',
#   '1',
#   'benzin',
#   'opel',
#   '',
#   '2016-03-26 00:00:00',
#   '0',
#   '56412',
#   '2016-03-27 17:43:34\n'],
#  ['2016-03-30 20:38:20',
#   'E_500_Avantgarde_AMG_Ausstattung',
#   'privat',
#   'Angebot',
#   '7500',
#   'control',
#   'limousine',
#   '2002',
#   'automatik',
#   '306',
#   'e_klasse',
#   '150000',
#   '4',
#   '',
#   'mercedes_benz',
#   '',
#   '2016-03-30 00:00:00',
#   '0',
#   '33649',
#   '2016-04-03 11:44:49\n'],
#  ['2016-03-24 00:52:09',
#   'BMW_E60_530XD',
#   'privat',
#   'Angebot',
#   '12500',
#   'test',
#   'limousine',
#   '2006',
#   'automatik',
#   '231',
#   '5er',
#   '150000',
#   '11',
#   'diesel',
#   'bmw',
#   '',
#   '2016-03-23 00:00:00',
#   '0',
#   '46119',
#   '2016-04-04 16:18:19\n'],
#  ['2016-03-13 15:47:08',
#   'Mini_One_Pepper_Scheckheftgepflegt',
#   'privat',
#   'Angebot',
#   '6990',
#   'test',
#   'limousine',
#   '2007',
#   'manuell',
#   '95',
#   'one',
#   '100000',
#   '8',
#   'benzin',
#   'mini',
#   'nein',
#   '2016-03-13 00:00:00',
#   '0',
#   '59174',
#   '2016-03-21 17:17:50\n'],
#  ['2016-03-17 12:44:43',
#   'Smart_For_two_Klima_regensensor_uSw',
#   'privat',
#   'Angebot',
#   '3900',
#   'test',
#   'kleinwagen',
#   '2008',
#   'automatik',
#   '61',
#   'fortwo',
#   '80000',
#   '6',
#   'benzin',
#   'smart',
#   '',
#   '2016-03-17 00:00:00',
#   '0',
#   '21073',
#   '2016-03-19 11:46:17\n'],
#  ['2016-03-29 18:57:46',
#   'Renault_Clio_1.4',
#   'privat',
#   'Angebot',
#   '590',
#   'control',
#   'kleinwagen',
#   '1999',
#   'manuell',
#   '75',
#   'clio',
#   '125000',
#   '8',
#   'benzin',
#   'renault',
#   'nein',
#   '2016-03-29 00:00:00',
#   '0',
#   '84180',
#   '2016-03-29 18:57:46\n'],
#  ['2016-03-15 18:59:02',
#   'BMW_120d_DPF',
#   'privat',
#   'Angebot',
#   '7999',
#   'control',
#   'limousine',
#   '2007',
#   'manuell',
#   '177',
#   '1er',
#   '150000',
#   '8',
#   'diesel',
#   'bmw',
#   'nein',
#   '2016-03-15 00:00:00',
#   '0',
#   '53604',
#   '2016-03-16 16:47:48\n'],
#  ['2016-04-04 00:38:22',
#   'BMW_528i_touring',
#   'privat',
#   'Angebot',
#   '2100',
#   'test',
#   'kombi',
#   '1998',
#   'automatik',
#   '193',
#   '5er',
#   '150000',
#   '2',
#   'benzin',
#   'bmw',
#   'nein',
#   '2016-04-03 00:00:00',
#   '0',
#   '86157',
#   '2016-04-06 08:16:21\n'],
#  ['2016-03-25 14:40:12',
#   'VW_Golf_6___Klima___Alu___Scheckheft_!!!',
#   'privat',
#   'Angebot',
#   '7750',
#   'control',
#   '',
#   '2017',
#   'manuell',
#   '80',
#   'golf',
#   '100000',
#   '1',
#   'benzin',
#   'volkswagen',
#   '',
#   '2016-03-25 00:00:00',
#   '0',
#   '48499',
#   '2016-03-31 21:47:44\n'],
#  ['2016-04-04 14:06:22',
#   'Mercedes_Benz_B180_Automatik',
#   'privat',
#   'Angebot',
#   '13500',
#   'test',
#   'bus',
#   '2012',
#   'automatik',
#   '109',
#   'b_klasse',
#   '150000',
#   '7',
#   'diesel',
#   'mercedes_benz',
#   'nein',
#   '2016-04-04 00:00:00',
#   '0',
#   '35576',
#   '2016-04-05 12:09:29\n'],
#  ['2016-03-30 08:50:37',
#   'BMW_120i_Cabrio_mit_M_Paket',
#   'privat',
#   'Angebot',
#   '14800',
#   'control',
#   'cabrio',
#   '2008',
#   'manuell',
#   '170',
#   '1er',
#   '125000',
#   '4',
#   'benzin',
#   'bmw',
#   '',
#   '2016-03-30 00:00:00',
#   '0',
#   '48691',
#   '2016-04-07 00:17:23\n'],
#  ['2016-03-07 18:57:08',
#   'Fiat_punto_5_tuerer__6_gang',
#   'privat',
#   'Angebot',
#   '2000',
#   'control',
#   '',
#   '2017',
#   'manuell',
#   '90',
#   'punto',
#   '150000',
#   '11',
#   'diesel',
#   'fiat',
#   'ja',
#   '2016-03-07 00:00:00',
#   '0',
#   '66115',
#   '2016-03-07 18:57:08\n'],
#  ['2016-04-04 10:57:36',
#   'Verkaufe_meinen_kleinen_wegen_neu_Anschaffung',
#   'privat',
#   'Angebot',
#   '1400',
#   'control',
#   '',
#   '2016',
#   'manuell',
#   '55',
#   'andere',
#   '5000',
#   '1',
#   '',
#   'hyundai',
#   '',
#   '2016-04-04 00:00:00',
#   '0',
#   '34454',
#   '2016-04-06 12:45:43\n'],
#  ['2016-03-29 18:53:48',
#   'Bmw_318_d_Sport_Edition_Facelift',
#   'privat',
#   'Angebot',
#   '7999',
#   'control',
#   'limousine',
#   '2008',
#   'automatik',
#   '143',
#   '3er',
#   '150000',
#   '12',
#   'diesel',
#   'bmw',
#   '',
#   '2016-03-29 00:00:00',
#   '0',
#   '71083',
#   '2016-04-06 04:45:54\n'],
#  ['2016-03-17 07:56:40',
#   'Opel_signum_1.9_cdti',
#   'privat',
#   'Angebot',
#   '4700',
#   'control',
#   'kombi',
#   '2005',
#   'manuell',
#   '0',
#   'signum',
#   '150000',
#   '0',
#   '',
#   'opel',
#   'nein',
#   '2016-03-17 00:00:00',
#   '0',
#   '88433',
#   '2016-04-04 04:17:32\n'],
#  ['2016-03-26 10:39:35',
#   'auto_opel_astra',
#   'privat',
#   'Angebot',
#   '550',
#   'test',
#   'kombi',
#   '1999',
#   'manuell',
#   '0',
#   'astra',
#   '150000',
#   '8',
#   'diesel',
#   'opel',
#   'ja',
#   '2016-03-26 00:00:00',
#   '0',
#   '56759',
#   '2016-04-01 23:17:27\n'],
#  ['2016-03-21 01:59:07',
#   'BMW_435i_Sport_coupe',
#   'privat',
#   'Angebot',
#   '39600',
#   'test',
#   'coupe',
#   '2014',
#   'automatik',
#   '306',
#   'andere',
#   '30000',
#   '7',
#   'benzin',
#   'bmw',
#   'nein',
#   '2016-03-21 00:00:00',
#   '0',
#   '10435',
#   '2016-04-03 23:16:31\n'],
#  ['2016-03-22 17:56:12',
#   'Smart_Cabrio_TÜV_bis_07/17',
#   'privat',
#   'Angebot',
#   '3000',
#   'control',
#   'cabrio',
#   '2006',
#   'automatik',
#   '61',
#   'fortwo',
#   '80000',
#   '1',
#   'benzin',
#   'smart',
#   'nein',
#   '2016-03-22 00:00:00',
#   '0',
#   '12055',
#   '2016-03-22 17:56:12\n'],
#  ['2016-03-10 20:53:19',
#   'Seat_inca_1.9SDI___LKW_Zulassung___TÜV_NEU',
#   'privat',
#   'Angebot',
#   '2399',
#   'test',
#   '',
#   '2018',
#   'manuell',
#   '64',
#   'andere',
#   '125000',
#   '3',
#   '',
#   'seat',
#   'nein',
#   '2016-03-10 00:00:00',
#   '0',
#   '33397',
#   '2016-03-25 10:17:37\n'],
#  ['2016-03-31 08:57:44',
#   'Volkswagen_Golf_1.6_Comfortline',
#   'privat',
#   'Angebot',
#   '1000',
#   'control',
#   'limousine',
#   '1998',
#   'manuell',
#   '101',
#   'golf',
#   '150000',
#   '10',
#   'benzin',
#   'volkswagen',
#   'nein',
#   '2016-03-31 00:00:00',
#   '0',
#   '39624',
#   '2016-04-06 03:15:47\n'],
#  ['2016-03-29 15:48:15',
#   'TAUSCHE_BMW_E38_740i_g._SUV_/_GELÄNDEWAGEN_LESEN_LESEN',
#   'privat',
#   'Angebot',
#   '1',
#   'control',
#   'suv',
#   '1994',
#   'manuell',
#   '286',
#   '',
#   '150000',
#   '11',
#   '',
#   'sonstige_autos',
#   '',
#   '2016-03-29 00:00:00',
#   '0',
#   '53721',
#   '2016-04-06 01:44:38\n'],
#  ['2016-03-26 07:54:29',
#   'Bmw_316i_compact.____200\x80',
#   'privat',
#   'Angebot',
#   '200',
#   'test',
#   'coupe',
#   '1995',
#   'manuell',
#   '102',
#   '3er',
#   '150000',
#   '4',
#   'benzin',
#   'bmw',
#   '',
#   '2016-03-26 00:00:00',
#   '0',
#   '23560',
#   '2016-04-01 20:46:51\n'],
#  ['2016-03-25 19:44:06',
#   'Audi_A8_3.0_TDI_quattro',
#   'privat',
#   'Angebot',
#   '7499',
#   'test',
#   'limousine',
#   '2004',
#   'automatik',
#   '232',
#   'a8',
#   '150000',
#   '3',
#   'diesel',
#   'audi',
#   'ja',
#   '2016-03-25 00:00:00',
#   '0',
#   '71711',
#   '2016-04-07 01:44:24\n'],
#  ['2016-03-30 12:49:54',
#   'Skoda_Fabia_1.2',
#   'privat',
#   'Angebot',
#   '5500',
#   'control',
#   'kleinwagen',
#   '2010',
#   'manuell',
#   '60',
#   'fabia',
#   '70000',
#   '4',
#   'benzin',
#   'skoda',
#   'nein',
#   '2016-03-30 00:00:00',
#   '0',
#   '57076',
#   '2016-04-07 03:44:51\n'],
#  ['2016-03-08 12:54:47',
#   'Volkswagen_Jetta_1.9_TDI_DSG_DPF_Sportline',
#   'privat',
#   'Angebot',
#   '7000',
#   'test',
#   'limousine',
#   '2006',
#   'automatik',
#   '105',
#   'jetta',
#   '100000',
#   '10',
#   'diesel',
#   'volkswagen',
#   'nein',
#   '2016-03-08 00:00:00',
#   '0',
#   '06242',
#   '2016-03-11 17:16:18\n'],
#  ['2016-03-07 22:36:54',
#   'BMW_325_i_Cabrio_wenig_Kilometer',
#   'privat',
#   'Angebot',
#   '14999',
#   'test',
#   'cabrio',
#   '2007',
#   'manuell',
#   '218',
#   '3er',
#   '50000',
#   '8',
#   'benzin',
#   'bmw',
#   'nein',
#   '2016-03-07 00:00:00',
#   '0',
#   '01129',
#   '2016-03-15 10:17:59\n'],
#  ['2016-03-28 17:41:27',
#   'Opel_Astra_1.4_mit_vielen_Extras!!!!',
#   'privat',
#   'Angebot',
#   '10900',
#   'test',
#   '',
#   '2017',
#   'manuell',
#   '101',
#   'astra',
#   '50000',
#   '3',
#   '',
#   'opel',
#   'nein',
#   '2016-03-28 00:00:00',
#   '0',
#   '63607',
#   '2016-04-06 23:15:52\n'],
#  ['2016-03-15 14:50:24',
#   'Volkswagen_Scirocco_1.4_TSI___Top_Zustand_!!!!',
#   'privat',
#   'Angebot',
#   '9700',
#   'test',
#   'coupe',
#   '2008',
#   'manuell',
#   '160',
#   'scirocco',
#   '150000',
#   '8',
#   'benzin',
#   'volkswagen',
#   'nein',
#   '2016-03-15 00:00:00',
#   '0',
#   '55218',
#   '2016-04-06 04:17:09\n'],
#  ['2016-03-21 12:47:55',
#   'Honda_HRV_reserviert!!!',
#   'privat',
#   'Angebot',
#   '2100',
#   'control',
#   'suv',
#   '2000',
#   'manuell',
#   '105',
#   'andere',
#   '150000',
#   '8',
#   'benzin',
#   'honda',
#   'nein',
#   '2016-02-09 00:00:00',
#   '0',
#   '85244',
#   '2016-03-31 16:46:09\n'],
#  ['2016-03-15 09:51:05',
#   'Mercedes_Benz_190',
#   'privat',
#   'Angebot',
#   '1280',
#   'control',
#   'limousine',
#   '1992',
#   'automatik',
#   '109',
#   'andere',
#   '150000',
#   '9',
#   'benzin',
#   'mercedes_benz',
#   '',
#   '2016-03-15 00:00:00',
#   '0',
#   '86163',
#   '2016-04-05 19:18:21\n'],
#  ['2016-04-01 11:56:40',
#   'Opel_astra_g_coupe_1.8_liter_benziner',
#   'privat',
#   'Angebot',
#   '1200',
#   'test',
#   'coupe',
#   '2001',
#   '',
#   '0',
#   'astra',
#   '150000',
#   '0',
#   '',
#   'opel',
#   '',
#   '2016-04-01 00:00:00',
#   '0',
#   '47249',
#   '2016-04-07 08:46:07\n'],
#  ['2016-03-08 01:36:42',
#   'Volkswagen_Polo',
#   'privat',
#   'Angebot',
#   '800',
#   'control',
#   'kleinwagen',
#   '1993',
#   'manuell',
#   '0',
#   'polo',
#   '150000',
#   '3',
#   'benzin',
#   'volkswagen',
#   'nein',
#   '2016-03-08 00:00:00',
#   '0',
#   '08258',
#   '2016-04-05 23:46:00\n'],
#  ['2016-03-07 08:55:18',
#   'BMW_520i_E39',
#   'privat',
#   'Angebot',
#   '2300',
#   'control',
#   '',
#   '1997',
#   'manuell',
#   '150',
#   '5er',
#   '150000',
#   '3',
#   '',
#   'bmw',
#   'nein',
#   '2016-03-07 00:00:00',
#   '0',
#   '79341',
#   '2016-03-22 05:15:22\n'],
#  ['2016-03-05 16:45:05',
#   'Ford_Fiesta',
#   'privat',
#   'Angebot',
#   '750',
#   'control',
#   'kleinwagen',
#   '2002',
#   'manuell',
#   '50',
#   'fiesta',
#   '150000',
#   '4',
#   'benzin',
#   'ford',
#   'nein',
#   '2016-03-05 00:00:00',
#   '0',
#   '70327',
#   '2016-03-11 06:16:00\n'],
#  ['2016-03-22 17:45:41',
#   'Mercedes_Benz_C_180_T_Kompressor_Avantgarde',
#   'privat',
#   'Angebot',
#   '7999',
#   'control',
#   'kombi',
#   '2008',
#   'manuell',
#   '156',
#   'c_klasse',
#   '150000',
#   '10',
#   'benzin',
#   'mercedes_benz',
#   'nein',
#   '2016-03-22 00:00:00',
#   '0',
#   '83355',
#   '2016-03-25 09:47:43\n'],
#  ['2016-03-31 18:46:36',
#   'VW_Golf_V_Plus_TDI_1_8',
#   'privat',
#   'Angebot',
#   '6600',
#   'control',
#   'limousine',
#   '2006',
#   'manuell',
#   '105',
#   'golf',
#   '150000',
#   '10',
#   'diesel',
#   'volkswagen',
#   'nein',
#   '2016-03-31 00:00:00',
#   '0',
#   '41812',
#   '2016-03-31 18:46:36\n'],
#  ['2016-03-17 09:48:12',
#   'Nissan_Micra_1.2_CVT',
#   'privat',
#   'Angebot',
#   '7999',
#   'test',
#   'kleinwagen',
#   '2013',
#   'manuell',
#   '80',
#   'micra',
#   '40000',
#   '4',
#   'benzin',
#   'nissan',
#   'nein',
#   '2016-03-17 00:00:00',
#   '0',
#   '46145',
#   '2016-04-06 07:44:23\n'],
#  ['2016-03-11 14:50:52',
#   'MB_Vito_Transporter_108_CDI',
#   'privat',
#   'Angebot',
#   '1400',
#   'control',
#   'andere',
#   '2003',
#   'manuell',
#   '82',
#   'vito',
#   '150000',
#   '8',
#   'diesel',
#   'mercedes_benz',
#   'nein',
#   '2016-03-11 00:00:00',
#   '0',
#   '04668',
#   '2016-03-11 14:50:52\n'],
#  ['2016-03-31 22:48:06',
#   'Golf_4_TDi_1_9.__3_tuerig',
#   'privat',
#   'Angebot',
#   '800',
#   'test',
#   '',
#   '2000',
#   'manuell',
#   '90',
#   'golf',
#   '150000',
#   '2',
#   'diesel',
#   'volkswagen',
#   '',
#   '2016-03-31 00:00:00',
#   '0',
#   '32584',
#   '2016-04-06 19:15:22\n'],
#  ['2016-03-10 10:50:26',
#   'Mercedes_Benz_311_CDI_Sprinter_DOKA_6_SITZ._TÜV/AU_NEU',
#   'privat',
#   'Angebot',
#   '5000',
#   'test',
#   'bus',
#   '2006',
#   'manuell',
#   '109',
#   'sprinter',
#   '150000',
#   '4',
#   'diesel',
#   'mercedes_benz',
#   'nein',
#   '2016-03-10 00:00:00',
#   '0',
#   '26382',
#   '2016-03-12 14:45:39\n'],
#  ['2016-03-11 23:42:53',
#   'Mercedes_Benz_E_250_CDI_Mod.2011_Automatik_NAVI_XENON_Glasdach',
#   'privat',
#   'Angebot',
#   '20300',
#   'test',
#   'limousine',
#   '2010',
#   'automatik',
#   '204',
#   'e_klasse',
#   '80000',
#   '12',
#   'diesel',
#   'mercedes_benz',
#   'nein',
#   '2016-03-11 00:00:00',
#   '0',
#   '51491',
#   '2016-04-03 01:26:23\n'],
#  ['2016-03-17 18:52:56',
#   'Opel_Astra_F_Cabrio',
#   'privat',
#   'Angebot',
#   '150',
#   'control',
#   '',
#   '2016',
#   'manuell',
#   '75',
#   'astra',
#   '150000',
#   '3',
#   'benzin',
#   'opel',
#   'ja',
#   '2016-03-17 00:00:00',
#   '0',
#   '78315',
#   '2016-04-05 03:45:22\n'],
#  ['2016-04-01 22:39:35',
#   'muss_dringend_weg_!!!_2_mal_Alfa_romeo_156_Zu_Verkaufen',
#   'privat',
#   'Angebot',
#   '250',
#   'test',
#   'kombi',
#   '2000',
#   'manuell',
#   '155',
#   '156',
#   '150000',
#   '0',
#   'benzin',
#   'alfa_romeo',
#   'ja',
#   '2016-04-01 00:00:00',
#   '0',
#   '08396',
#   '2016-04-05 20:18:14\n'],
#  ['2016-04-03 12:56:45',
#   'Bastler_Fahrzeug_mit_Rest_Tuev',
#   'privat',
#   'Angebot',
#   '350',
#   'control',
#   'kleinwagen',
#   '1997',
#   'manuell',
#   '54',
#   '',
#   '150000',
#   '3',
#   '',
#   'fiat',
#   'ja',
#   '2016-04-03 00:00:00',
#   '0',
#   '45665',
#   '2016-04-05 11:47:13\n'],
#  ['2016-03-09 21:46:09',
#   'Ford_Escort_CLX',
#   'privat',
#   'Angebot',
#   '600',
#   'test',
#   'limousine',
#   '1994',
#   'manuell',
#   '75',
#   'escort',
#   '100000',
#   '6',
#   'benzin',
#   'ford',
#   'ja',
#   '2016-03-09 00:00:00',
#   '0',
#   '37359',
#   '2016-04-05 23:44:25\n'],
#  ['2016-03-23 18:59:37',
#   'Mercedes_Benz_C_220_T_CDI_Avantgarde',
#   'privat',
#   'Angebot',
#   '3300',
#   'test',
#   'kombi',
#   '2005',
#   'manuell',
#   '150',
#   'c_klasse',
#   '150000',
#   '9',
#   'diesel',
#   'mercedes_benz',
#   'ja',
#   '2016-03-23 00:00:00',
#   '0',
#   '29221',
#   '2016-03-23 18:59:37\n'],
#  ['2016-03-12 19:46:54',
#   'SUBARU_FORESTER',
#   'privat',
#   'Angebot',
#   '1600',
#   'test',
#   'kombi',
#   '1997',
#   'automatik',
#   '122',
#   'forester',
#   '150000',
#   '10',
#   'benzin',
#   'subaru',
#   'nein',
#   '2016-03-12 00:00:00',
#   '0',
#   '87497',
#   '2016-03-15 06:46:18\n'],
#  ['2016-03-29 14:58:15',
#   'Volvo_XC90_AWD_D5_Kinetic_Leder_Standheizung_AHK_Gruene_Umweltpl',
#   'privat',
#   'Angebot',
#   '8000',
#   'test',
#   'suv',
#   '2005',
#   'manuell',
#   '185',
#   'xc_reihe',
#   '150000',
#   '8',
#   'diesel',
#   'volvo',
#   '',
#   '2016-03-29 00:00:00',
#   '0',
#   '96472',
#   '2016-04-03 23:18:17\n'],
#  ['2016-03-13 19:52:34',
#   'Mitsubishi_L_400',
#   'privat',
#   'Angebot',
#   '1800',
#   'control',
#   'bus',
#   '2001',
#   'manuell',
#   '87',
#   'andere',
#   '150000',
#   '7',
#   'diesel',
#   'mitsubishi',
#   'nein',
#   '2016-03-13 00:00:00',
#   '0',
#   '24116',
#   '2016-03-17 13:47:41\n'],
#  ['2016-03-08 13:49:57',
#   'Fiesta_Titanium_1.25',
#   'privat',
#   'Angebot',
#   '6800',
#   'control',
#   'kleinwagen',
#   '2009',
#   'manuell',
#   '82',
#   'fiesta',
#   '60000',
#   '12',
#   'benzin',
#   'ford',
#   'nein',
#   '2016-03-08 00:00:00',
#   '0',
#   '51065',
#   '2016-04-05 19:18:01\n'],
#  ['2016-03-07 17:38:57',
#   'Renault_Scenic',
#   'privat',
#   'Angebot',
#   '2990',
#   'test',
#   'bus',
#   '2004',
#   'manuell',
#   '113',
#   'scenic',
#   '150000',
#   '12',
#   'benzin',
#   'renault',
#   'nein',
#   '2016-03-07 00:00:00',
#   '0',
#   '41836',
#   '2016-03-09 06:15:31\n'],
#  ['2016-03-28 09:37:01',
#   'MERCEDES_BENZ_W124_250D_83KW_/_113PS___SCHLACHTFEST_!!!_Preis:_1\x80',
#   'privat',
#   'Angebot',
#   '1',
#   'control',
#   'limousine',
#   '1995',
#   'manuell',
#   '113',
#   'e_klasse',
#   '150000',
#   '4',
#   'diesel',
#   'mercedes_benz',
#   'nein',
#   '2016-03-28 00:00:00',
#   '0',
#   '40589',
#   '2016-04-06 12:15:54\n'],
#  ['2016-03-23 11:53:21',
#   'A4_Diesel_Leder_Top___NAVI',
#   'privat',
#   'Angebot',
#   '2400',
#   'test',
#   'limousine',
#   '2003',
#   'manuell',
#   '0',
#   'a4',
#   '150000',
#   '9',
#   'diesel',
#   'audi',
#   '',
#   '2016-03-23 00:00:00',
#   '0',
#   '40210',
#   '2016-03-23 11:53:21\n'],
#  ['2016-04-02 23:25:25',
#   'Senator_A2__3_0E__180PS__CD_Ausstattung.',
#   'privat',
#   'Angebot',
#   '1222',
#   'control',
#   'limousine',
#   '1984',
#   'automatik',
#   '180',
#   'andere',
#   '150000',
#   '3',
#   'benzin',
#   'opel',
#   '',
#   '2016-04-02 00:00:00',
#   '0',
#   '57290',
#   '2016-04-06 14:44:57\n'],
#  ['2016-03-16 07:56:19',
#   'FORD_KA___TÜV_ABGELAUFEN',
#   'privat',
#   'Angebot',
#   '250',
#   'control',
#   '',
#   '2000',
#   '',
#   '60',
#   'ka',
#   '150000',
#   '0',
#   '',
#   'ford',
#   '',
#   '2016-03-16 00:00:00',
#   '0',
#   '51427',
#   '2016-03-21 09:47:08\n'],
#  ['2016-03-10 11:44:54',
#   'Audi_A1_1.2_TFSI_S_Line',
#   'privat',
#   'Angebot',
#   '14500',
#   'test',
#   'kleinwagen',
#   '2013',
#   'manuell',
#   '86',
#   'a1',
#   '60000',
#   '4',
#   'benzin',
#   'audi',
#   'nein',
#   '2016-03-10 00:00:00',
#   '0',
#   '31582',
#   '2016-04-07 01:15:35\n'],
#  ['2016-03-28 16:37:43',
#   'unfall_Opel_insignia_voll_Ausstattung__TÜV_neu__ideal_fuer_Bastler',
#   'privat',
#   'Angebot',
#   '8390',
#   'test',
#   '',
#   '2009',
#   '',
#   '0',
#   'insignia',
#   '150000',
#   '0',
#   '',
#   'opel',
#   '',
#   '2016-03-28 00:00:00',
#   '0',
#   '29221',
#   '2016-03-30 07:44:59\n'],
#  ['2016-03-25 18:44:10',
#   'Volkswagen_Passat_1.9_TDI',
#   'privat',
#   'Angebot',
#   '3850',
#   'test',
#   'limousine',
#   '2003',
#   'manuell',
#   '131',
#   'passat',
#   '150000',
#   '5',
#   'diesel',
#   'volkswagen',
#   'nein',
#   '2016-03-25 00:00:00',
#   '0',
#   '30459',
#   '2016-04-07 00:16:18\n'],
#  ['2016-03-31 10:53:10',
#   'BMW_318d_Aut.__Xenon__Navi__Sportsitze_FESTREIS!',
#   'privat',
#   'Angebot',
#   '23490',
#   'control',
#   'limousine',
#   '2013',
#   'automatik',
#   '143',
#   '3er',
#   '40000',
#   '6',
#   'diesel',
#   'bmw',
#   'nein',
#   '2016-03-31 00:00:00',
#   '0',
#   '49356',
#   '2016-04-06 03:44:40\n'],
#  ['2016-03-26 15:38:12',
#   'VW_t5_kastenwagen',
#   'privat',
#   'Angebot',
#   '6450',
#   'test',
#   'bus',
#   '2008',
#   'manuell',
#   '84',
#   'transporter',
#   '150000',
#   '12',
#   '',
#   'volkswagen',
#   'nein',
#   '2016-03-26 00:00:00',
#   '0',
#   '44623',
#   '2016-04-06 03:17:37\n'],
#  ['2016-04-01 12:45:41',
#   'Mercedes_A_Klasse____Top_Zustand___TÜV/AU___neu_!_Halbautomatik',
#   'privat',
#   'Angebot',
#   '1700',
#   'test',
#   'kleinwagen',
#   '1999',
#   'automatik',
#   '102',
#   'a_klasse',
#   '125000',
#   '11',
#   'benzin',
#   'mercedes_benz',
#   'nein',
#   '2016-04-01 00:00:00',
#   '0',
#   '12305',
#   '2016-04-01 12:45:41\n'],
#  ['2016-03-11 19:00:25',
#   'OPEL_COMBO_2008__TÜV_Neu_bis_02.2018__DIESEL___LKW_ZULLASUNG',
#   'privat',
#   'Angebot',
#   '4290',
#   'test',
#   'bus',
#   '2008',
#   'manuell',
#   '0',
#   'combo',
#   '150000',
#   '2',
#   'diesel',
#   'opel',
#   'nein',
#   '2016-03-11 00:00:00',
#   '0',
#   '23568',
#   '2016-04-05 22:45:32\n'],
#  ['2016-03-28 00:56:46',
#   'Ford_Focus_Turnier_1.6_TDCi_DPF',
#   'privat',
#   'Angebot',
#   '1500',
#   'control',
#   'kombi',
#   '2006',
#   'manuell',
#   '109',
#   'focus',
#   '150000',
#   '10',
#   'diesel',
#   'ford',
#   'nein',
#   '2016-03-27 00:00:00',
#   '0',
#   '74223',
#   '2016-04-02 11:47:00\n'],
#  ['2016-03-15 17:41:31',
#   'Audi_A4_B5_1_6_Liter',
#   'privat',
#   'Angebot',
#   '499',
#   'control',
#   'limousine',
#   '1995',
#   'manuell',
#   '101',
#   'a4',
#   '150000',
#   '5',
#   'benzin',
#   'audi',
#   '',
#   '2016-03-15 00:00:00',
#   '0',
#   '85414',
#   '2016-03-22 20:48:22\n'],
#  ['2016-03-16 16:44:10',
#   'Hyundai_Genesis_Coupe_GT_3.8_V6_Automatik',
#   'privat',
#   'Angebot',
#   '22999',
#   'control',
#   'coupe',
#   '2012',
#   'automatik',
#   '303',
#   'andere',
#   '50000',
#   '4',
#   'benzin',
#   'hyundai',
#   'nein',
#   '2016-03-16 00:00:00',
#   '0',
#   '88167',
#   '2016-04-06 20:18:22\n'],
#  ['2016-04-01 09:54:39',
#   'Audi_a4_2.5_TDI_Tausch_moeglich',
#   'privat',
#   'Angebot',
#   '6500',
#   'test',
#   'limousine',
#   '2004',
#   'manuell',
#   '163',
#   'a4',
#   '150000',
#   '4',
#   'diesel',
#   'audi',
#   '',
#   '2016-04-01 00:00:00',
#   '0',
#   '97450',
#   '2016-04-01 09:54:39\n'],
#  ['2016-03-26 07:36:20',
#   'verkaufe_Mercedes_Benz_220_CDI_Sport_8_fach_Bereift',
#   'privat',
#   'Angebot',
#   '900',
#   'test',
#   'kombi',
#   '1999',
#   'manuell',
#   '125',
#   'c_klasse',
#   '150000',
#   '7',
#   'diesel',
#   'mercedes_benz',
#   'nein',
#   '2016-03-26 00:00:00',
#   '0',
#   '37130',
#   '2016-03-29 11:44:47\n'],
#  ['2016-03-21 10:47:53',
#   'BMW_316_automatikgetriebe_Klimaanlage',
#   'privat',
#   'Angebot',
#   '650',
#   'test',
#   'limousine',
#   '1997',
#   'automatik',
#   '102',
#   '3er',
#   '150000',
#   '8',
#   'benzin',
#   'bmw',
#   '',
#   '2016-03-21 00:00:00',
#   '0',
#   '13357',
#   '2016-03-22 14:49:21\n'],
#  ['2016-03-20 12:59:39',
#   'Ford_Escort_Cabrio',
#   'privat',
#   'Angebot',
#   '300',
#   'test',
#   'cabrio',
#   '1992',
#   'manuell',
#   '105',
#   'escort',
#   '150000',
#   '0',
#   '',
#   'ford',
#   'ja',
#   '2016-03-20 00:00:00',
#   '0',
#   '88515',
#   '2016-04-06 13:15:58\n'],
#  ['2016-04-02 12:54:14',
#   'Audi_TT_Coupe_1.8_T_quattro',
#   'privat',
#   'Angebot',
#   '3399',
#   'test',
#   'coupe',
#   '1999',
#   'manuell',
#   '224',
#   'tt',
#   '150000',
#   '9',
#   'benzin',
#   'audi',
#   'ja',
#   '2016-04-02 00:00:00',
#   '0',
#   '61276',
#   '2016-04-05 19:44:33\n'],
#  ['2016-03-23 10:59:51',
#   'Volkswagen_Passat_Variant_1.6_Kombi_mit_TÜV_und_AHK',
#   'privat',
#   'Angebot',
#   '1300',
#   'control',
#   'kombi',
#   '1997',
#   'manuell',
#   '101',
#   'passat',
#   '150000',
#   '10',
#   'benzin',
#   'volkswagen',
#   'nein',
#   '2016-03-23 00:00:00',
#   '0',
#   '04277',
#   '2016-03-29 04:46:48\n'],
#  ['2016-03-16 23:25:21',
#   'Honda_Civic_EG4',
#   'privat',
#   'Angebot',
#   '900',
#   'test',
#   '',
#   '1995',
#   'manuell',
#   '90',
#   'civic',
#   '150000',
#   '3',
#   'benzin',
#   'honda',
#   '',
#   '2016-03-16 00:00:00',
#   '0',
#   '35789',
#   '2016-03-19 17:19:00\n'],
#  ['2016-03-22 17:44:26',
#   '530d_XDRIVE_235_PS',
#   'privat',
#   'Angebot',
#   '7300',
#   'control',
#   'limousine',
#   '2009',
#   'automatik',
#   '235',
#   '5er',
#   '100000',
#   '3',
#   'diesel',
#   'bmw',
#   'nein',
#   '2016-03-22 00:00:00',
#   '0',
#   '83022',
#   '2016-03-22 17:44:26\n'],
#  ['2016-03-26 15:47:58',
#   'Opel_Astra_Twin_Top_2.0_Turbo',
#   'privat',
#   'Angebot',
#   '8599',
#   'test',
#   'cabrio',
#   '2006',
#   'manuell',
#   '200',
#   'astra',
#   '125000',
#   '9',
#   'benzin',
#   'opel',
#   'nein',
#   '2016-03-26 00:00:00',
#   '0',
#   '79761',
#   '2016-04-06 04:15:35\n'],
#  ['2016-04-03 03:57:26',
#   'Opel_Corsa_TÜV_bis_Ende_2016',
#   'privat',
#   'Angebot',
#   '350',
#   'test',
#   'kleinwagen',
#   '1998',
#   '',
#   '0',
#   'corsa',
#   '150000',
#   '2',
#   'benzin',
#   'opel',
#   '',
#   '2016-04-03 00:00:00',
#   '0',
#   '82110',
#   '2016-04-03 08:53:37\n'],
#  ['2016-03-19 18:40:12',
#   'Golf_IV_1.4_16V',
#   'privat',
#   'Angebot',
#   '0',
#   'test',
#   '',
#   '2017',
#   'manuell',
#   '0',
#   'golf',
#   '5000',
#   '12',
#   'benzin',
#   'volkswagen',
#   '',
#   '2016-03-19 00:00:00',
#   '0',
#   '21698',
#   '2016-04-01 08:47:05\n'],
#  ['2016-03-14 20:37:41',
#   'Audi_A6_2_5_TDi_Quattro_Avant_Automatic__Turbo__Kombi__132_KW__2_',
#   'privat',
#   'Angebot',
#   '5900',
#   'control',
#   'kombi',
#   '2005',
#   'automatik',
#   '178',
#   'a6',
#   '150000',
#   '1',
#   'diesel',
#   'audi',
#   'nein',
#   '2016-03-14 00:00:00',
#   '0',
#   '88131',
#   '2016-04-06 07:17:00\n'],
#  ['2016-03-20 18:38:02',
#   'Volkswagen_Golf_1.8_5V_Turbo',
#   'privat',
#   'Angebot',
#   '6300',
#   'test',
#   'limousine',
#   '2002',
#   'manuell',
#   '265',
#   'golf',
#   '150000',
#   '3',
#   'benzin',
#   'volkswagen',
#   'nein',
#   '2016-03-20 00:00:00',
#   '0',
#   '56759',
#   '2016-04-07 01:45:06\n'],
#  ['2016-04-04 09:50:15',
#   'Volkswagen_Corrado_1.8_G60',
#   'privat',
#   'Angebot',
#   '3500',
#   'control',
#   'coupe',
#   '1991',
#   'manuell',
#   '160',
#   'andere',
#   '150000',
#   '5',
#   'benzin',
#   'volkswagen',
#   'nein',
#   '2016-04-04 00:00:00',
#   '0',
#   '66111',
#   '2016-04-06 11:17:02\n'],
#  ['2016-03-20 18:53:27',
#   'Polo_6n_Karosse_zu_verschenken',
#   'privat',
#   'Angebot',
#   '0',
#   'test',
#   'kleinwagen',
#   '1999',
#   '',
#   '0',
#   '',
#   '5000',
#   '0',
#   'benzin',
#   'volkswagen',
#   '',
#   '2016-03-20 00:00:00',
#   '0',
#   '37520',
#   '2016-04-07 02:45:22\n'],
#  ['2016-03-09 17:47:24',
#   'BMW_320d_DPF',
#   'privat',
#   'Angebot',
#   '5950',
#   'test',
#   'limousine',
#   '2006',
#   'manuell',
#   '163',
#   '3er',
#   '150000',
#   '1',
#   'diesel',
#   'bmw',
#   'ja',
#   '2016-03-09 00:00:00',
#   '0',
#   '63526',
#   '2016-03-10 14:15:41\n'],
#  ['2016-04-03 12:45:29',
#   'Honda_Jazz_1.2_S',
#   'privat',
#   'Angebot',
#   '1699',
#   'control',
#   'kleinwagen',
#   '2003',
#   'manuell',
#   '77',
#   'jazz',
#   '150000',
#   '8',
#   'benzin',
#   'honda',
#   'nein',
#   '2016-04-03 00:00:00',
#   '0',
#   '42105',
#   '2016-04-07 14:57:35\n'],
#  ['2016-03-20 13:54:32',
#   'Volkswagen_vw_t4_Einzelstueck',
#   'privat',
#   'Angebot',
#   '4699',
#   'test',
#   'bus',
#   '1996',
#   'manuell',
#   '110',
#   'transporter',
#   '150000',
#   '8',
#   'benzin',
#   'volkswagen',
#   'nein',
#   '2016-03-20 00:00:00',
#   '0',
#   '79713',
#   '2016-03-25 13:45:30\n'],
#  ['2016-03-23 12:54:52',
#   'Motorschaden_steuerrichmen_gerissen',
#   'privat',
#   'Angebot',
#   '400',
#   'control',
#   'limousine',
#   '2000',
#   'manuell',
#   '144',
#   'omega',
#   '150000',
#   '10',
#   '',
#   'opel',
#   'ja',
#   '2016-03-23 00:00:00',
#   '0',
#   '45968',
#   '2016-04-05 12:45:13\n'],
#  ['2016-03-12 22:57:58',
#   'Volkswagen_Polo_1.4_FSI_Team',
#   'privat',
#   'Angebot',
#   '9290',
#   'control',
#   'kleinwagen',
#   '2010',
#   'manuell',
#   '86',
#   'polo',
#   '40000',
#   '5',
#   'benzin',
#   'volkswagen',
#   'nein',
#   '2016-03-12 00:00:00',
#   '0',
#   '35630',
#   '2016-03-26 06:17:39\n'],
#  ['2016-03-18 11:25:43',
#   'Mercedes_Benz_Kabrio__Limousine___mit_Gas_Umbau....',
#   'privat',
#   'Angebot',
#   '7000',
#   'control',
#   'limousine',
#   '2003',
#   'manuell',
#   '120',
#   'slk',
#   '150000',
#   '5',
#   'benzin',
#   'mercedes_benz',
#   'nein',
#   '2016-03-18 00:00:00',
#   '0',
#   '57578',
#   '2016-03-23 08:44:31\n'],
#  ['2016-04-01 17:56:34',
#   'Servo_Klima_Zv__usw',
#   'privat',
#   'Angebot',
#   '1199',
#   'test',
#   'kleinwagen',
#   '2000',
#   'manuell',
#   '60',
#   'twingo',
#   '150000',
#   '5',
#   'benzin',
#   'renault',
#   'nein',
#   '2016-04-01 00:00:00',
#   '0',
#   '28832',
#   '2016-04-05 13:44:57\n'],
#  ['2016-03-27 12:36:18',
#   'Ford_Focus_1_6l*Klima*TÜV*',
#   'privat',
#   'Angebot',
#   '1750',
#   'test',
#   'limousine',
#   '2002',
#   'manuell',
#   '75',
#   'focus',
#   '125000',
#   '1',
#   'benzin',
#   'ford',
#   'nein',
#   '2016-03-27 00:00:00',
#   '0',
#   '33330',
#   '2016-03-27 12:36:18\n'],
#  ['2016-03-18 23:41:18',
#   'Volkswagen_Golf_CL',
#   'privat',
#   'Angebot',
#   '1000',
#   'test',
#   'limousine',
#   '1990',
#   'manuell',
#   '54',
#   'golf',
#   '150000',
#   '2',
#   'benzin',
#   'volkswagen',
#   'nein',
#   '2016-03-18 00:00:00',
#   '0',
#   '47447',
#   '2016-04-05 23:16:13\n'],
#  ['2016-03-11 20:55:37',
#   'BMW_740i',
#   'privat',
#   'Angebot',
#   '1800',
#   'control',
#   'limousine',
#   '1995',
#   'automatik',
#   '286',
#   '7er',
#   '150000',
#   '12',
#   'benzin',
#   'bmw',
#   'ja',
#   '2016-03-11 00:00:00',
#   '0',
#   '77866',
#   '2016-03-20 10:17:59\n'],
#  ['2016-03-20 10:54:17',
#   'VW_Golf_6_1.4_Comfortline',
#   'privat',
#   'Angebot',
#   '8000',
#   'control',
#   '',
#   '2009',
#   'manuell',
#   '0',
#   'golf',
#   '100000',
#   '10',
#   'benzin',
#   'volkswagen',
#   'nein',
#   '2016-03-20 00:00:00',
#   '0',
#   '94139',
#   '2016-04-06 07:45:51\n'],
#  ['2016-03-16 18:37:43',
#   'Opel_Combo_1.7_DTI___Kasten___Lkw_Zulassung___Euro3',
#   'privat',
#   'Angebot',
#   '1100',
#   'control',
#   'bus',
#   '2003',
#   'manuell',
#   '75',
#   'combo',
#   '150000',
#   '3',
#   'diesel',
#   'opel',
#   'nein',
#   '2016-03-16 00:00:00',
#   '0',
#   '96224',
#   '2016-03-24 11:46:38\n'],
#  ['2016-03-09 20:37:42',
#   'Mercedes_Benz_E_270_T_CDI',
#   'privat',
#   'Angebot',
#   '2990',
#   'test',
#   'kombi',
#   '2001',
#   'automatik',
#   '170',
#   'e_klasse',
#   '150000',
#   '1',
#   'diesel',
#   'mercedes_benz',
#   'nein',
#   '2016-03-09 00:00:00',
#   '0',
#   '53520',
#   '2016-03-17 02:45:51\n'],
#  ['2016-03-26 19:37:55',
#   'Opel_Corsa_1.0_TÜV_bis_01/17',
#   'privat',
#   'Angebot',
#   '300',
#   'control',
#   'kleinwagen',
#   '2000',
#   'manuell',
#   '54',
#   'corsa',
#   '150000',
#   '0',
#   'benzin',
#   'opel',
#   '',
#   '2016-03-26 00:00:00',
#   '0',
#   '59379',
#   '2016-04-06 09:15:51\n'],
#  ['2016-03-20 18:47:31',
#   'BMW_E36_328i_Coupe_Schalter',
#   'privat',
#   'Angebot',
#   '3390',
#   'test',
#   '',
#   '2000',
#   '',
#   '0',
#   '3er',
#   '150000',
#   '2',
#   '',
#   'bmw',
#   '',
#   '2016-03-20 00:00:00',
#   '0',
#   '45739',
#   '2016-03-28 19:48:42\n'],
#  ['2016-03-31 20:57:02',
#   'Volkswagen_Passat',
#   'privat',
#   'Angebot',
#   '2750',
#   'test',
#   'kombi',
#   '2001',
#   'manuell',
#   '131',
#   'passat',
#   '150000',
#   '12',
#   'diesel',
#   'volkswagen',
#   'nein',
#   '2016-03-31 00:00:00',
#   '0',
#   '90471',
#   '2016-04-06 16:45:33\n'],
#  ['2016-03-28 20:45:46',
#   'Fabia_II_Combi_Greenline_1_2_TDI_DPF_mit_Gebrauchtwagengarantie',
#   'privat',
#   'Angebot',
#   '6990',
#   'control',
#   'kombi',
#   '2012',
#   'manuell',
#   '75',
#   'fabia',
#   '100000',
#   '5',
#   'diesel',
#   'skoda',
#   'nein',
#   '2016-03-28 00:00:00',
#   '0',
#   '44894',
#   '2016-04-03 13:58:00\n'],
#  ['2016-04-01 22:55:34',
#   'Audi_Cabriolet_Typ_89_2.0L',
#   'privat',
#   'Angebot',
#   '4800',
#   'test',
#   'cabrio',
#   '1996',
#   'manuell',
#   '116',
#   '80',
#   '150000',
#   '6',
#   'benzin',
#   'audi',
#   'nein',
#   '2016-04-01 00:00:00',
#   '0',
#   '38300',
#   '2016-04-05 23:46:14\n'],
#  ['2016-03-21 16:45:30',
#   'Mercedes_Benz_C_220_CDI_DPF_Automatik_Avantgarde',
#   'privat',
#   'Angebot',
#   '14499',
#   'control',
#   'limousine',
#   '2007',
#   'automatik',
#   '170',
#   'c_klasse',
#   '125000',
#   '5',
#   'diesel',
#   'mercedes_benz',
#   'nein',
#   '2016-03-21 00:00:00',
#   '0',
#   '13439',
#   '2016-04-06 15:45:36\n'],
#  ['2016-03-27 20:51:23',
#   'Audi_80_5_Zylinder_b4_liebhaberfahrzeug',
#   'privat',
#   'Angebot',
#   '1450',
#   'control',
#   'limousine',
#   '1992',
#   'manuell',
#   '136',
#   '',
#   '150000',
#   '0',
#   '',
#   'audi',
#   'nein',
#   '2016-03-27 00:00:00',
#   '0',
#   '38709',
#   '2016-04-05 20:17:31\n'],
#  ['2016-04-03 15:58:09',
#   'Verkaufe_ein_toppen_golf5',
#   'privat',
#   'Angebot',
#   '4300',
#   'test',
#   'limousine',
#   '2005',
#   'manuell',
#   '90',
#   'golf',
#   '150000',
#   '11',
#   'diesel',
#   'volkswagen',
#   '',
#   '2016-04-03 00:00:00',
#   '0',
#   '28779',
#   '2016-04-05 15:46:23\n'],
#  ['2016-03-24 14:38:41',
#   'Honda_Civic_1.6i',
#   'privat',
#   'Angebot',
#   '2499',
#   'test',
#   'limousine',
#   '2003',
#   'manuell',
#   '110',
#   'civic',
#   '150000',
#   '12',
#   'benzin',
#   'honda',
#   '',
#   '2016-03-24 00:00:00',
#   '0',
#   '42853',
#   '2016-03-24 14:38:41\n'],
#  ['2016-04-02 10:59:28',
#   'Alfa_Romeo_147_1.9_JTD_8V_M_Jet__DPF',
#   'privat',
#   'Angebot',
#   '3450',
#   'test',
#   'limousine',
#   '2007',
#   'manuell',
#   '120',
#   '147',
#   '150000',
#   '4',
#   'diesel',
#   'alfa_romeo',
#   'nein',
#   '2016-04-02 00:00:00',
#   '0',
#   '86678',
#   '2016-04-04 07:51:11\n'],
#  ['2016-04-01 15:53:08',
#   'Mercedes_Benz_C180_mit_TÜV',
#   'privat',
#   'Angebot',
#   '350',
#   'test',
#   'limousine',
#   '1996',
#   'manuell',
#   '122',
#   'c_klasse',
#   '150000',
#   '9',
#   'benzin',
#   'mercedes_benz',
#   '',
#   '2016-04-01 00:00:00',
#   '0',
#   '49685',
#   '2016-04-05 10:48:41\n'],
#  ['2016-03-13 01:57:12',
#   'BMW_530d_touring',
#   'privat',
#   'Angebot',
#   '3550',
#   'control',
#   'kombi',
#   '2000',
#   'automatik',
#   '184',
#   '5er',
#   '150000',
#   '11',
#   'diesel',
#   'bmw',
#   'nein',
#   '2016-03-13 00:00:00',
#   '0',
#   '72525',
#   '2016-04-06 08:45:19\n'],
#  ['2016-03-28 19:06:18',
#   'Sehr_gepflegter_unfallfreier_Ford_C_Max_Style+_1_6_DPF_mit_AHK',
#   'privat',
#   'Angebot',
#   '8250',
#   'test',
#   'bus',
#   '2010',
#   'manuell',
#   '109',
#   'c_max',
#   '125000',
#   '10',
#   'diesel',
#   'ford',
#   'nein',
#   '2016-03-28 00:00:00',
#   '0',
#   '35606',
#   '2016-04-07 04:44:59\n'],
#  ['2016-03-09 09:51:36',
#   'renault_clio_TÜV_NEU_bis_03_2018_inzahlungname_moeglich',
#   'privat',
#   'Angebot',
#   '800',
#   'test',
#   'kleinwagen',
#   '1998',
#   'manuell',
#   '54',
#   'clio',
#   '150000',
#   '11',
#   'benzin',
#   'renault',
#   'nein',
#   '2016-03-09 00:00:00',
#   '0',
#   '34516',
#   '2016-03-14 11:46:52\n'],
#  ['2016-03-14 12:46:46',
#   'Audi_A4_b5_Avant_TÜV_10/17',
#   'privat',
#   'Angebot',
#   '1500',
#   'test',
#   'kombi',
#   '1996',
#   'manuell',
#   '126',
#   'a4',
#   '150000',
#   '0',
#   '',
#   'audi',
#   'nein',
#   '2016-03-14 00:00:00',
#   '0',
#   '24873',
#   '2016-03-17 00:45:29\n'],
#  ['2016-03-31 00:59:04',
#   'Mercedes_Benz_GLK_250_BlueTEC_4Matic_Standhzg_Alcantara_Voll',
#   'privat',
#   'Angebot',
#   '41900',
#   'control',
#   'suv',
#   '2014',
#   'automatik',
#   '204',
#   'glk',
#   '40000',
#   '9',
#   'diesel',
#   'mercedes_benz',
#   'nein',
#   '2016-03-30 00:00:00',
#   '0',
#   '82131',
#   '2016-04-06 01:17:24\n'],
#  ['2016-04-05 09:55:37',
#   'BMW_330d_schadow_line',
#   'privat',
#   'Angebot',
#   '4200',
#   'control',
#   'kombi',
#   '2003',
#   'automatik',
#   '204',
#   '3er',
#   '150000',
#   '1',
#   'diesel',
#   'bmw',
#   'nein',
#   '2016-04-05 00:00:00',
#   '0',
#   '53757',
#   '2016-04-07 13:16:46\n'],
#  ['2016-03-06 21:38:00',
#   'Audi_100_c3_typ_44_bj_1985_quattro_krarosse_mit_achsen',
#   'privat',
#   'Angebot',
#   '150',
#   'control',
#   '',
#   '1985',
#   '',
#   '0',
#   '100',
#   '150000',
#   '4',
#   'benzin',
#   'audi',
#   '',
#   '2016-03-06 00:00:00',
#   '0',
#   '87616',
#   '2016-04-07 02:16:59\n'],
#  ['2016-03-27 12:59:00',
#   'Volkswagen_Golf_3',
#   'privat',
#   'Angebot',
#   '1000',
#   'test',
#   'kleinwagen',
#   '1996',
#   'manuell',
#   '75',
#   'golf',
#   '150000',
#   '3',
#   'benzin',
#   'volkswagen',
#   'nein',
#   '2016-03-27 00:00:00',
#   '0',
#   '38640',
#   '2016-04-01 12:45:50\n'],
#  ['2016-03-15 12:50:00',
#   'Krankenfahrstuhl_25_kmh__zu_verkaufen.',
#   'privat',
#   'Angebot',
#   '300',
#   'control',
#   '',
#   '2005',
#   'manuell',
#   '0',
#   'punto',
#   '40000',
#   '9',
#   '',
#   'fiat',
#   'ja',
#   '2016-03-15 00:00:00',
#   '0',
#   '26215',
#   '2016-03-25 04:19:17\n'],
#  ['2016-03-09 12:50:41',
#   'Peugeot_307_90_Grand_Filou',
#   'privat',
#   'Angebot',
#   '800',
#   'control',
#   'limousine',
#   '2004',
#   'manuell',
#   '88',
#   '3_reihe',
#   '150000',
#   '9',
#   'benzin',
#   'peugeot',
#   'ja',
#   '2016-03-09 00:00:00',
#   '0',
#   '66333',
#   '2016-03-20 06:18:20\n'],
#  ['2016-03-22 10:50:53',
#   'Mercedes_C_200_Kompressor',
#   'privat',
#   'Angebot',
#   '2300',
#   'control',
#   'limousine',
#   '2000',
#   'manuell',
#   '160',
#   'c_klasse',
#   '150000',
#   '5',
#   'benzin',
#   'mercedes_benz',
#   'nein',
#   '2016-03-22 00:00:00',
#   '0',
#   '40231',
#   '2016-03-22 11:41:11\n'],
#  ['2016-03-29 07:56:29',
#   'Audi_A6_Avant_2_5tdi*Navi*Automatik*Euro4*',
#   'privat',
#   'Angebot',
#   '4000',
#   'test',
#   'kombi',
#   '2003',
#   'automatik',
#   '163',
#   'a6',
#   '150000',
#   '6',
#   'diesel',
#   'audi',
#   'nein',
#   '2016-03-29 00:00:00',
#   '0',
#   '22525',
#   '2016-03-31 01:47:16\n'],
#  ['2016-03-27 20:47:22',
#   'POLO_1.2_KILIMA_WIE_NEU',
#   'privat',
#   'Angebot',
#   '6799',
#   'control',
#   'kleinwagen',
#   '2009',
#   '',
#   '60',
#   '',
#   '20000',
#   '5',
#   'benzin',
#   'volkswagen',
#   'nein',
#   '2016-03-27 00:00:00',
#   '0',
#   '89077',
#   '2016-03-27 20:47:22\n'],
#  ['2016-03-11 18:55:53',
#   'Opel_meriva_1.6_16_v_lpg__z16xe_no_OPC',
#   'privat',
#   'Angebot',
#   '0',
#   'test',
#   'bus',
#   '2004',
#   'manuell',
#   '101',
#   'meriva',
#   '150000',
#   '10',
#   'lpg',
#   'opel',
#   'ja',
#   '2016-03-11 00:00:00',
#   '0',
#   '27432',
#   '2016-03-12 23:47:10\n'],
#  ['2016-04-03 18:58:25',
#   'BMW_Z4_roadster_2.2i_M_Paket__Klima__Xenon',
#   'privat',
#   'Angebot',
#   '9450',
#   'control',
#   'cabrio',
#   '2004',
#   'manuell',
#   '170',
#   'z_reihe',
#   '150000',
#   '12',
#   'benzin',
#   'bmw',
#   'nein',
#   '2016-04-03 00:00:00',
#   '0',
#   '65549',
#   '2016-04-07 11:15:22\n'],
#  ['2016-03-22 16:37:59',
#   'Fiat_Scudo_Bulli_Werkstattwagen_Diesel',
#   'privat',
#   'Angebot',
#   '0',
#   'test',
#   '',
#   '2006',
#   '',
#   '0',
#   'andere',
#   '5000',
#   '0',
#   '',
#   'fiat',
#   '',
#   '2016-03-22 00:00:00',
#   '0',
#   '44867',
#   '2016-04-06 06:17:56\n'],
#  ['2016-03-09 12:53:53',
#   'KIA_SPORTAGE',
#   'privat',
#   'Angebot',
#   '14500',
#   'control',
#   '',
#   '2017',
#   'manuell',
#   '136',
#   'sportage',
#   '125000',
#   '5',
#   'diesel',
#   'kia',
#   'nein',
#   '2016-03-09 00:00:00',
#   '0',
#   '49696',
#   '2016-04-05 23:45:15\n'],
#  ['2016-03-10 16:57:31',
#   'Mercedes_Benz_C_270_CDI_Elegance',
#   'privat',
#   'Angebot',
#   '6890',
#   'control',
#   'limousine',
#   '2003',
#   'manuell',
#   '170',
#   'c_klasse',
#   '125000',
#   '2',
#   'diesel',
#   'mercedes_benz',
#   'nein',
#   '2016-03-10 00:00:00',
#   '0',
#   '55743',
#   '2016-04-01 20:47:57\n'],
#  ['2016-03-23 14:45:57',
#   'Kia_Sorento__coole_Farbe_schaut......',
#   'privat',
#   'Angebot',
#   '7500',
#   'test',
#   'suv',
#   '2007',
#   'automatik',
#   '194',
#   'sorento',
#   '5000',
#   '11',
#   'benzin',
#   'kia',
#   '',
#   '2016-03-23 00:00:00',
#   '0',
#   '34314',
#   '2016-04-05 15:47:51\n'],
#  ['2016-04-01 16:06:24',
#   'Volkswagen_Golf_Function',
#   'privat',
#   'Angebot',
#   '800',
#   'control',
#   'limousine',
#   '1993',
#   'manuell',
#   '0',
#   'golf',
#   '10000',
#   '9',
#   'benzin',
#   'volkswagen',
#   'ja',
#   '2016-04-01 00:00:00',
#   '0',
#   '65929',
#   '2016-04-07 11:17:07\n'],
#  ['2016-03-08 19:58:07',
#   'A_210_Evolution_AMG_Styling_absoluter_Festpreis',
#   'privat',
#   'Angebot',
#   '1499',
#   'test',
#   'kleinwagen',
#   '2002',
#   'manuell',
#   '140',
#   'a_klasse',
#   '150000',
#   '10',
#   '',
#   'mercedes_benz',
#   'nein',
#   '2016-03-08 00:00:00',
#   '0',
#   '16727',
#   '2016-03-10 17:44:36\n'],
#  ['2016-03-19 19:49:15',
#   'is_ales_ok',
#   'privat',
#   'Angebot',
#   '500',
#   'control',
#   'kleinwagen',
#   '1999',
#   'manuell',
#   '0',
#   '',
#   '150000',
#   '0',
#   'benzin',
#   'renault',
#   'nein',
#   '2016-03-19 00:00:00',
#   '0',
#   '26969',
#   '2016-04-01 11:17:48\n'],
#  ['2016-03-28 10:50:04',
#   'VW_Caddy_Lkw_Zulassung',
#   'privat',
#   'Angebot',
#   '1495',
#   'control',
#   'kombi',
#   '2001',
#   '',
#   '64',
#   '',
#   '150000',
#   '9',
#   'diesel',
#   'volkswagen',
#   '',
#   '2016-03-28 00:00:00',
#   '0',
#   '99086',
#   '2016-04-04 11:45:46\n'],
#  ['2016-03-30 10:50:00',
#   'Mitsubishi_Space_ohne_TÜV',
#   'privat',
#   'Angebot',
#   '300',
#   'test',
#   'kleinwagen',
#   '1994',
#   'manuell',
#   '0',
#   'andere',
#   '150000',
#   '7',
#   'benzin',
#   'mitsubishi',
#   '',
#   '2016-03-30 00:00:00',
#   '0',
#   '26340',
#   '2016-03-30 10:50:00\n'],
#  ['2016-04-04 12:57:02',
#   'OPEL_astra_G_TÜV_NEU',
#   'privat',
#   'Angebot',
#   '1200',
#   'control',
#   '',
#   '2018',
#   'manuell',
#   '75',
#   'astra',
#   '150000',
#   '0',
#   '',
# ...
#   'manuell',
#   '120',
#   'andere',
#   '150000',
#   '1',
#   'diesel',
#   'citroen',
#   'nein',
#   '2016-03-27 00:00:00',
#   '0',
#   '67071',
#   '2016-04-07 09:46:23\n'],
#  ['2016-03-31 16:36:22',
#   'Golf_3_1.6_75PS__BBS__Gewinde_',
#   'privat',
#   'Angebot',
#   '1450',
#   'control',
#   '',
#   '2016',
#   'manuell',
#   '75',
#   '',
#   '150000',
#   '10',
#   'benzin',
#   'volkswagen',
#   'nein',
#   '2016-03-31 00:00:00',
#   '0',
#   '24109',
#   '2016-04-06 10:46:15\n'],
#  ['2016-03-15 17:48:56',
#   'Kia_Picanto_1.1_LX',
#   'privat',
#   'Angebot',
#   '2300',
#   'control',
#   'kleinwagen',
#   '2006',
#   'manuell',
#   '65',
#   'picanto',
#   '50000',
#   '12',
#   'benzin',
#   'kia',
#   'nein',
#   '2016-03-15 00:00:00',
#   '0',
#   '10997',
#   '2016-03-16 15:18:40\n'],
#  ['2016-03-30 21:50:24',
#   'Ford_Fiesta_Mk4',
#   'privat',
#   'Angebot',
#   '250',
#   'test',
#   'kleinwagen',
#   '1998',
#   'manuell',
#   '60',
#   '',
#   '100000',
#   '0',
#   '',
#   'ford',
#   '',
#   '2016-03-30 00:00:00',
#   '0',
#   '21354',
#   '2016-03-30 21:50:24\n'],
#  ['2016-04-06 18:06:35',
#   'Rover_75_Tourer_2.0_V6',
#   'privat',
#   'Angebot',
#   '2500',
#   'control',
#   'kombi',
#   '2001',
#   'automatik',
#   '150',
#   'andere',
#   '150000',
#   '11',
#   'benzin',
#   'rover',
#   'ja',
#   '2016-04-06 00:00:00',
#   '0',
#   '56170',
#   '2016-04-06 18:25:20\n'],
#  ['2016-03-28 14:43:23',
#   'Fiat_Punto___Diesel___Silber___1.9_JTD___80_PS___Gebraucht',
#   'privat',
#   'Angebot',
#   '1099',
#   'test',
#   'kleinwagen',
#   '2001',
#   'manuell',
#   '80',
#   'punto',
#   '150000',
#   '4',
#   'diesel',
#   'fiat',
#   '',
#   '2016-03-28 00:00:00',
#   '0',
#   '22117',
#   '2016-03-31 22:45:41\n'],
#  ['2016-03-08 14:53:30',
#   'Nissan_Micra_1.2',
#   'privat',
#   'Angebot',
#   '3999',
#   'test',
#   'kleinwagen',
#   '2009',
#   'manuell',
#   '65',
#   'micra',
#   '40000',
#   '7',
#   'benzin',
#   'nissan',
#   'nein',
#   '2016-03-08 00:00:00',
#   '0',
#   '04639',
#   '2016-04-06 03:17:10\n'],
#  ['2016-03-10 14:56:56',
#   'Mercedes_Benz_Mercedes_Benz_E_280_W210_4_Matic_Servis_Schekhef',
#   'privat',
#   'Angebot',
#   '3500',
#   'test',
#   'limousine',
#   '1997',
#   'automatik',
#   '204',
#   'e_klasse',
#   '150000',
#   '10',
#   'benzin',
#   'mercedes_benz',
#   'nein',
#   '2016-03-10 00:00:00',
#   '0',
#   '63452',
#   '2016-04-05 11:49:13\n'],
#  ['2016-03-17 18:56:07',
#   'Volkswagen_T5_California',
#   'privat',
#   'Angebot',
#   '44900',
#   'control',
#   'bus',
#   '2015',
#   'manuell',
#   '140',
#   'transporter',
#   '10000',
#   '5',
#   'diesel',
#   'volkswagen',
#   'nein',
#   '2016-03-17 00:00:00',
#   '0',
#   '78166',
#   '2016-04-07 06:16:53\n'],
#  ['2016-03-29 15:51:51',
#   'Opel_Corsa_1.3_Cdti_ERSTE_HAND_gruene_Plakette_Guter_Zustand',
#   'privat',
#   'Angebot',
#   '2399',
#   'control',
#   'kleinwagen',
#   '2004',
#   'manuell',
#   '0',
#   'corsa',
#   '150000',
#   '11',
#   'diesel',
#   'opel',
#   'nein',
#   '2016-03-29 00:00:00',
#   '0',
#   '41569',
#   '2016-04-04 00:18:11\n'],
#  ['2016-03-22 18:56:48',
#   'Opel_Zafira_1.8_Njoy_mit_Style_Paket',
#   'privat',
#   'Angebot',
#   '2600',
#   'control',
#   'bus',
#   '2005',
#   'manuell',
#   '125',
#   'zafira',
#   '150000',
#   '5',
#   'benzin',
#   'opel',
#   'nein',
#   '2016-03-22 00:00:00',
#   '0',
#   '37539',
#   '2016-03-25 11:47:17\n'],
#  ['2016-03-27 21:54:42',
#   'Volkswagen_Sharan_1.9_TDI_Family',
#   'privat',
#   'Angebot',
#   '1950',
#   'test',
#   'bus',
#   '2002',
#   'manuell',
#   '116',
#   'sharan',
#   '150000',
#   '10',
#   'diesel',
#   'volkswagen',
#   'nein',
#   '2016-03-27 00:00:00',
#   '0',
#   '41462',
#   '2016-03-27 21:54:42\n'],
#  ['2016-03-07 13:53:53',
#   'Porsche_Boxster_Top_Gepflegt_Navi__Xenon__Hardtop',
#   'privat',
#   'Angebot',
#   '10450',
#   'control',
#   'cabrio',
#   '2001',
#   'manuell',
#   '220',
#   'boxster',
#   '150000',
#   '3',
#   'benzin',
#   'porsche',
#   'nein',
#   '2016-03-07 00:00:00',
#   '0',
#   '06844',
#   '2016-04-06 12:44:22\n'],
#  ['2016-03-26 18:44:52',
#   'Top_transporter_mit_wenig_km',
#   'privat',
#   'Angebot',
#   '3100',
#   'test',
#   'andere',
#   '2001',
#   'manuell',
#   '90',
#   '',
#   '70000',
#   '7',
#   'diesel',
#   'kia',
#   'nein',
#   '2016-03-26 00:00:00',
#   '0',
#   '39218',
#   '2016-04-06 07:45:41\n'],
#  ['2016-03-14 18:55:19',
#   'Smart_smart_crossblade',
#   'privat',
#   'Angebot',
#   '14000',
#   'test',
#   'cabrio',
#   '2003',
#   'manuell',
#   '71',
#   'andere',
#   '5000',
#   '8',
#   'benzin',
#   'smart',
#   'nein',
#   '2016-03-14 00:00:00',
#   '0',
#   '66271',
#   '2016-04-02 05:18:16\n'],
#  ['2016-03-17 19:40:22',
#   'Punto_Model_188',
#   'privat',
#   'Angebot',
#   '190',
#   'control',
#   'kleinwagen',
#   '1999',
#   'manuell',
#   '0',
#   'punto',
#   '150000',
#   '4',
#   'benzin',
#   'fiat',
#   'ja',
#   '2016-03-17 00:00:00',
#   '0',
#   '63911',
#   '2016-03-17 19:40:22\n'],
#  ['2016-03-25 15:45:10',
#   'BMW_530d',
#   'privat',
#   'Angebot',
#   '17000',
#   'test',
#   'limousine',
#   '2005',
#   'manuell',
#   '231',
#   '5er',
#   '150000',
#   '10',
#   'diesel',
#   'bmw',
#   'nein',
#   '2016-03-25 00:00:00',
#   '0',
#   '78647',
#   '2016-04-06 19:16:53\n'],
#  ['2016-03-25 12:49:40',
#   'BMW_318d_DPF_Touring',
#   'privat',
#   'Angebot',
#   '11599',
#   'test',
#   'kombi',
#   '2010',
#   'manuell',
#   '143',
#   '3er',
#   '150000',
#   '4',
#   'diesel',
#   'bmw',
#   'nein',
#   '2016-03-25 00:00:00',
#   '0',
#   '51147',
#   '2016-04-06 14:16:56\n'],
#  ['2016-04-04 15:47:10',
#   'BMW_120d_M_paket_Sportsitze..',
#   'privat',
#   'Angebot',
#   '9800',
#   'test',
#   'kombi',
#   '2006',
#   'manuell',
#   '0',
#   '1er',
#   '150000',
#   '10',
#   '',
#   'bmw',
#   'nein',
#   '2016-04-04 00:00:00',
#   '0',
#   '51469',
#   '2016-04-06 17:17:35\n'],
#  ['2016-03-21 18:58:11',
#   'Renault_Clio_1.2_16V',
#   'privat',
#   'Angebot',
#   '1690',
#   'test',
#   'kleinwagen',
#   '2002',
#   'manuell',
#   '75',
#   'clio',
#   '125000',
#   '9',
#   'benzin',
#   'renault',
#   'nein',
#   '2016-03-21 00:00:00',
#   '0',
#   '70825',
#   '2016-04-06 21:47:14\n'],
#  ['2016-03-21 05:36:19',
#   'Mercedes_Benz_E_350_CDI_DPF_Cabrio_BlueEFFICIENCY_7G_TRONIC',
#   'privat',
#   'Angebot',
#   '30600',
#   'test',
#   'cabrio',
#   '2010',
#   'automatik',
#   '231',
#   'e_klasse',
#   '80000',
#   '5',
#   'diesel',
#   'mercedes_benz',
#   'nein',
#   '2016-03-21 00:00:00',
#   '0',
#   '71229',
#   '2016-03-21 09:42:42\n'],
#  ['2016-03-27 11:55:07',
#   'Ford_Focus_Turnier_/_Kombi___131PS__2_0l',
#   'privat',
#   'Angebot',
#   '1500',
#   'test',
#   'kombi',
#   '1999',
#   'manuell',
#   '131',
#   'focus',
#   '150000',
#   '3',
#   'benzin',
#   'ford',
#   'nein',
#   '2016-03-27 00:00:00',
#   '0',
#   '13593',
#   '2016-04-01 11:18:06\n'],
#  ['2016-03-31 00:32:39',
#   'Renault_Megane_1.6_"Bastler_Fahrzeug_oder_zum_ausschlachten"',
#   'privat',
#   'Angebot',
#   '140',
#   'test',
#   'coupe',
#   '1997',
#   'manuell',
#   '0',
#   'megane',
#   '150000',
#   '6',
#   'benzin',
#   'renault',
#   'ja',
#   '2016-03-30 00:00:00',
#   '0',
#   '60435',
#   '2016-04-05 17:26:10\n'],
#  ['2016-03-21 00:56:46',
#   'Mercedes_Benz_A_150_Avantgarde_W169_Automatik',
#   'privat',
#   'Angebot',
#   '5990',
#   'test',
#   'limousine',
#   '2007',
#   'automatik',
#   '95',
#   'a_klasse',
#   '150000',
#   '9',
#   'benzin',
#   'mercedes_benz',
#   'nein',
#   '2016-03-21 00:00:00',
#   '0',
#   '33014',
#   '2016-04-06 00:17:07\n'],
#  ['2016-03-17 14:48:30',
#   'VW_Golf3_Variant_Kombi_1.9l',
#   'privat',
#   'Angebot',
#   '1300',
#   'control',
#   'kombi',
#   '1996',
#   'manuell',
#   '75',
#   'golf',
#   '150000',
#   '12',
#   '',
#   'volkswagen',
#   'nein',
#   '2016-03-17 00:00:00',
#   '0',
#   '01809',
#   '2016-03-19 14:20:31\n'],
#  ['2016-03-20 16:41:53',
#   'Renault_Scenic_1.6_16V_RXE',
#   'privat',
#   'Angebot',
#   '1000',
#   'test',
#   'bus',
#   '2000',
#   'manuell',
#   '107',
#   'scenic',
#   '125000',
#   '6',
#   'benzin',
#   'renault',
#   'nein',
#   '2016-03-20 00:00:00',
#   '0',
#   '79739',
#   '2016-03-30 07:46:08\n'],
#  ['2016-03-21 14:54:00',
#   'Mercedes_Benz_C_220_CDI_Avantg._Panorama_PDC_SHZ_NAVI_VOLLEDER',
#   'privat',
#   'Angebot',
#   '11900',
#   'control',
#   'limousine',
#   '2008',
#   'manuell',
#   '170',
#   'c_klasse',
#   '125000',
#   '9',
#   'diesel',
#   'mercedes_benz',
#   'nein',
#   '2016-03-21 00:00:00',
#   '0',
#   '45888',
#   '2016-04-06 12:15:36\n'],
#  ['2016-04-05 13:25:18',
#   'BMW_316i',
#   'privat',
#   'Angebot',
#   '1400',
#   'control',
#   'limousine',
#   '2000',
#   'manuell',
#   '105',
#   '3er',
#   '150000',
#   '3',
#   'benzin',
#   'bmw',
#   'nein',
#   '2016-04-05 00:00:00',
#   '0',
#   '56073',
#   '2016-04-05 13:25:18\n'],
#  ['2016-03-09 18:06:18',
#   'Zu_verkaufen_nissan__micra',
#   'privat',
#   'Angebot',
#   '1450',
#   'control',
#   'kleinwagen',
#   '2003',
#   'manuell',
#   '0',
#   '',
#   '125000',
#   '0',
#   'benzin',
#   'nissan',
#   '',
#   '2016-03-09 00:00:00',
#   '0',
#   '60386',
#   '2016-03-10 19:36:38\n'],
#  ['2016-03-24 14:46:18',
#   'VW_Polo_/_Auffahrunfall__Scheckheftgepflegt_und_neue_Motorkette_',
#   'privat',
#   'Angebot',
#   '2000',
#   'test',
#   '',
#   '2016',
#   'manuell',
#   '59',
#   'polo',
#   '100000',
#   '0',
#   'benzin',
#   'volkswagen',
#   'ja',
#   '2016-03-24 00:00:00',
#   '0',
#   '22047',
#   '2016-03-24 14:46:18\n'],
#  ['2016-04-04 13:49:39',
#   'Suzuki_Vitara_TÜV_4x4_Allrad',
#   'privat',
#   'Angebot',
#   '1599',
#   'control',
#   '',
#   '2017',
#   'manuell',
#   '0',
#   '',
#   '150000',
#   '0',
#   'benzin',
#   'suzuki',
#   'nein',
#   '2016-04-04 00:00:00',
#   '0',
#   '97714',
#   '2016-04-06 15:16:26\n'],
#  ['2016-04-04 00:44:34',
#   'BMW_Z3_Roadster_Alpina...._Einer_der_ersten',
#   'privat',
#   'Angebot',
#   '4700',
#   'test',
#   'cabrio',
#   '1996',
#   'manuell',
#   '117',
#   'z_reihe',
#   '150000',
#   '8',
#   'benzin',
#   'bmw',
#   'nein',
#   '2016-04-03 00:00:00',
#   '0',
#   '31185',
#   '2016-04-06 03:44:28\n'],
#  ['2016-04-03 13:41:24',
#   'Verkaufe_VW_caddy_1.9_sdi',
#   'privat',
#   'Angebot',
#   '1400',
#   'control',
#   'andere',
#   '1997',
#   'manuell',
#   '0',
#   'caddy',
#   '150000',
#   '10',
#   'diesel',
#   'volkswagen',
#   'ja',
#   '2016-04-03 00:00:00',
#   '0',
#   '18246',
#   '2016-04-03 13:41:24\n'],
#  ['2016-03-27 20:55:55',
#   'Renault_Scenic_TOP_Familienauto',
#   'privat',
#   'Angebot',
#   '1100',
#   'control',
#   'bus',
#   '1999',
#   'manuell',
#   '107',
#   'scenic',
#   '150000',
#   '5',
#   'benzin',
#   'renault',
#   'nein',
#   '2016-03-27 00:00:00',
#   '0',
#   '66740',
#   '2016-03-29 11:18:08\n'],
#  ['2016-03-26 14:44:15',
#   'Opel_Vectra_2.8_V6_Turbo_Automatik_Cosmo',
#   'privat',
#   'Angebot',
#   '6990',
#   'control',
#   'limousine',
#   '2005',
#   'automatik',
#   '230',
#   'vectra',
#   '100000',
#   '12',
#   'benzin',
#   'opel',
#   'nein',
#   '2016-03-26 00:00:00',
#   '0',
#   '46047',
#   '2016-04-06 02:17:16\n'],
#  ['2016-03-07 18:57:15',
#   'Daewoo_Kalos',
#   'privat',
#   'Angebot',
#   '650',
#   'control',
#   'kleinwagen',
#   '2002',
#   '',
#   '0',
#   'kalos',
#   '20000',
#   '8',
#   '',
#   'daewoo',
#   'nein',
#   '2016-03-07 00:00:00',
#   '0',
#   '08371',
#   '2016-03-07 18:57:15\n'],
#  ['2016-04-06 19:25:24',
#   'Opel_Corsa_1.2_16V_Comfort',
#   'privat',
#   'Angebot',
#   '1400',
#   'control',
#   'kleinwagen',
#   '2002',
#   'manuell',
#   '75',
#   'corsa',
#   '150000',
#   '8',
#   'benzin',
#   'opel',
#   'nein',
#   '2016-04-06 00:00:00',
#   '0',
#   '65428',
#   '2016-04-06 19:25:24\n'],
#  ['2016-03-19 09:51:01',
#   'Skoda_Superb_Family__Kombi_2_0_l_Diesel_dunkelbraun',
#   'privat',
#   'Angebot',
#   '16700',
#   'test',
#   'kombi',
#   '2013',
#   '',
#   '140',
#   'superb',
#   '60000',
#   '6',
#   'diesel',
#   'skoda',
#   'nein',
#   '2016-03-19 00:00:00',
#   '0',
#   '42549',
#   '2016-03-24 02:44:24\n'],
#  ['2016-03-31 16:54:58',
#   'Honda_Civic_1.4_90ps_supersonic',
#   'privat',
#   'Angebot',
#   '2000',
#   'control',
#   'kleinwagen',
#   '1999',
#   'manuell',
#   '90',
#   'civic',
#   '150000',
#   '0',
#   '',
#   'honda',
#   'nein',
#   '2016-03-31 00:00:00',
#   '0',
#   '34621',
#   '2016-04-06 09:44:40\n'],
#  ['2016-03-10 13:51:28',
#   'Fiat_Stilo_Multi_Wagon_1.6_16V',
#   'privat',
#   'Angebot',
#   '3300',
#   'test',
#   'kombi',
#   '2004',
#   'manuell',
#   '103',
#   'stilo',
#   '150000',
#   '9',
#   'benzin',
#   'fiat',
#   'nein',
#   '2016-03-10 00:00:00',
#   '0',
#   '44801',
#   '2016-03-21 00:46:31\n'],
#  ['2016-03-23 07:54:25',
#   'Citroen_Berlingo_TÜV_neu_Anhaengerkupplung_Bremsen_neu',
#   'privat',
#   'Angebot',
#   '1400',
#   'control',
#   'kombi',
#   '1999',
#   'manuell',
#   '90',
#   'berlingo',
#   '150000',
#   '8',
#   'benzin',
#   'citroen',
#   'nein',
#   '2016-03-23 00:00:00',
#   '0',
#   '92345',
#   '2016-03-27 12:18:10\n'],
#  ['2016-04-03 14:39:43',
#   'Suzuki_Swift_1.0__D3_Norm_eFh_bei_Berlin',
#   'privat',
#   'Angebot',
#   '98',
#   'test',
#   'kleinwagen',
#   '1997',
#   'manuell',
#   '53',
#   'swift',
#   '150000',
#   '7',
#   'benzin',
#   'suzuki',
#   'nein',
#   '2016-04-03 00:00:00',
#   '0',
#   '14542',
#   '2016-04-05 13:18:15\n'],
#  ['2016-04-04 19:40:28',
#   'Hyundai__i30',
#   'privat',
#   'Angebot',
#   '14000',
#   'test',
#   'kombi',
#   '2013',
#   'manuell',
#   '99',
#   'i_reihe',
#   '30000',
#   '5',
#   'benzin',
#   'hyundai',
#   '',
#   '2016-04-04 00:00:00',
#   '0',
#   '49824',
#   '2016-04-06 21:45:32\n'],
#  ['2016-03-30 16:38:07',
#   'Toyota_Avensis_1.8_VVT_i_Combi',
#   'privat',
#   'Angebot',
#   '3800',
#   'test',
#   'kombi',
#   '2003',
#   'manuell',
#   '129',
#   'avensis',
#   '150000',
#   '6',
#   'benzin',
#   'toyota',
#   'nein',
#   '2016-03-30 00:00:00',
#   '0',
#   '26169',
#   '2016-04-07 07:15:47\n'],
#  ['2016-03-18 17:42:48',
#   'BMW_316_ti_Compact__Klima',
#   'privat',
#   'Angebot',
#   '790',
#   'test',
#   'kleinwagen',
#   '1996',
#   'manuell',
#   '102',
#   '3er',
#   '150000',
#   '5',
#   'benzin',
#   'bmw',
#   'nein',
#   '2016-03-18 00:00:00',
#   '0',
#   '86368',
#   '2016-03-22 11:15:15\n'],
#  ['2016-03-21 19:06:35',
#   'Mercedes_Benz_Vito_108_CDI_+_TÜV',
#   'privat',
#   'Angebot',
#   '1450',
#   'test',
#   'bus',
#   '2000',
#   'manuell',
#   '82',
#   'vito',
#   '150000',
#   '6',
#   'diesel',
#   'mercedes_benz',
#   'nein',
#   '2016-03-21 00:00:00',
#   '0',
#   '55120',
#   '2016-03-23 11:32:18\n'],
#  ['2016-03-27 22:54:11',
#   'Opel_zafira_1.9_CDTI_Navi__Panoramadach__Sitzheizung__Leder',
#   'privat',
#   'Angebot',
#   '5500',
#   'test',
#   'bus',
#   '2005',
#   'manuell',
#   '150',
#   'zafira',
#   '150000',
#   '10',
#   'diesel',
#   'opel',
#   'nein',
#   '2016-03-27 00:00:00',
#   '0',
#   '27749',
#   '2016-04-06 06:17:07\n'],
#  ['2016-03-08 15:49:58',
#   'Renault_Megane_fuer_150\x80_VB',
#   'privat',
#   'Angebot',
#   '150',
#   'test',
#   '',
#   '2016',
#   'manuell',
#   '0',
#   'megane',
#   '150000',
#   '0',
#   'benzin',
#   'renault',
#   '',
#   '2016-03-08 00:00:00',
#   '0',
#   '26871',
#   '2016-03-10 10:45:20\n'],
#  ['2016-03-26 19:47:19',
#   'Tausche_oder_verkaufe',
#   'privat',
#   'Angebot',
#   '0',
#   'control',
#   'kleinwagen',
#   '2000',
#   'manuell',
#   '0',
#   'corsa',
#   '150000',
#   '5',
#   'benzin',
#   'opel',
#   'nein',
#   '2016-03-26 00:00:00',
#   '0',
#   '26215',
#   '2016-03-26 19:47:19\n'],
#  ['2016-03-24 12:39:51',
#   'SEAT_ALHAMBRA_1_9TDI_unfallfrei_AHK__1.ter_Hand__12_Jahre',
#   'privat',
#   'Angebot',
#   '3650',
#   'test',
#   'bus',
#   '2003',
#   'manuell',
#   '116',
#   'alhambra',
#   '150000',
#   '12',
#   'diesel',
#   'seat',
#   'nein',
#   '2016-03-24 00:00:00',
#   '0',
#   '87779',
#   '2016-04-01 06:18:14\n'],
#  ['2016-03-14 10:53:52',
#   'Renault_Laguna',
#   'privat',
#   'Angebot',
#   '500',
#   'control',
#   'limousine',
#   '1999',
#   'manuell',
#   '0',
#   'laguna',
#   '150000',
#   '0',
#   'benzin',
#   'renault',
#   'ja',
#   '2016-03-14 00:00:00',
#   '0',
#   '14822',
#   '2016-04-07 11:18:03\n'],
#  ['2016-03-22 09:56:13',
#   'Fiat_Barchetta_1.8_16V',
#   'privat',
#   'Angebot',
#   '1999',
#   'test',
#   'cabrio',
#   '1996',
#   'manuell',
#   '131',
#   'andere',
#   '125000',
#   '4',
#   'benzin',
#   'fiat',
#   'nein',
#   '2016-03-22 00:00:00',
#   '0',
#   '83339',
#   '2016-03-23 17:48:06\n'],
#  ['2016-03-25 12:42:09',
#   'Porsche_997_GT3_MKII_EIN_SAMMLERSTÜCK_IN_VOLLAUSSTATTUNG',
#   'privat',
#   'Angebot',
#   '139997',
#   'test',
#   'coupe',
#   '2010',
#   'manuell',
#   '435',
#   '911',
#   '20000',
#   '3',
#   'benzin',
#   'porsche',
#   'nein',
#   '2016-03-25 00:00:00',
#   '0',
#   '71159',
#   '2016-04-06 13:45:07\n'],
#  ['2016-04-04 19:36:22',
#   'Smart_Fortwo_cabrio',
#   'privat',
#   'Angebot',
#   '3999',
#   'test',
#   'cabrio',
#   '2007',
#   'automatik',
#   '84',
#   'fortwo',
#   '150000',
#   '9',
#   'benzin',
#   'smart',
#   'nein',
#   '2016-04-04 00:00:00',
#   '0',
#   '50767',
#   '2016-04-04 19:36:22\n'],
#  ['2016-04-02 22:39:21',
#   'VW_pasat__1.9_tedi',
#   'privat',
#   'Angebot',
#   '2600',
#   'test',
#   '',
#   '2017',
#   'automatik',
#   '101',
#   'passat',
#   '150000',
#   '4',
#   'diesel',
#   'volkswagen',
#   '',
#   '2016-04-02 00:00:00',
#   '0',
#   '61197',
#   '2016-04-06 23:44:35\n'],
#  ['2016-03-26 13:50:33',
#   'Honda_Civic_Coupe_1.7_LS',
#   'privat',
#   'Angebot',
#   '1500',
#   'control',
#   'coupe',
#   '2001',
#   'manuell',
#   '120',
#   'civic',
#   '150000',
#   '3',
#   'benzin',
#   'honda',
#   'nein',
#   '2016-03-26 00:00:00',
#   '0',
#   '08058',
#   '2016-03-26 13:50:33\n'],
#  ...]

# %%
X = np.array(X)
X
# Out:
# array([['2016-03-24 11:52:17', 'Golf_3_1.6', 'privat', ..., '0', '70435',
#         '2016-04-07 03:16:57\n'],
#        ['2016-03-24 10:58:45', 'A5_Sportback_2.7_Tdi', 'privat', ...,
#         '0', '66954', '2016-04-07 01:46:50\n'],
#        ['2016-03-14 12:52:21', 'Jeep_Grand_Cherokee_"Overland"',
#         'privat', ..., '0', '90480', '2016-04-05 12:47:46\n'],
#        ...,
#        ['2016-03-19 18:57:12', 'Volkswagen_Multivan_T4_TDI_7DC_UY2',
#         'privat', ..., '0', '87439', '2016-04-07 07:15:26\n'],
#        ['2016-03-20 19:41:08', 'VW_Golf_Kombi_1_9l_TDI', 'privat', ...,
#         '0', '40764', '2016-03-24 12:45:21\n'],
#        ['2016-03-07 19:39:19',
#         'BMW_M135i_vollausgestattet_NP_52.720____Euro', 'privat', ...,
#         '0', '73326', '2016-03-22 03:17:10\n']], dtype='<U69')

# %%
X.shape
# Out:
# (371824, 20)

# %% [markdown]
# ### Wie können wir nun Daten einlesen mit Panda?

# %%
import pandas as pd
