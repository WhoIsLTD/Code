# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans

img = mpimg.imread("boy.jpg")

plt.imshow(img)
imgplot = plt.imshow(img)
plt.axis('on')
plt.show()

# %%
img.shape[2]
# Out:
# 3

# %%
X = img.reshape((img.shape[0]*img.shape[1], img.shape[2]))

# %%
print(X)
X.shape[1]
# Out:
# [[220 208 208]
#  [218 206 206]
#  [215 203 203]
#  ...
#  [218 122 123]
#  [221 123 124]
#  [223 125 126]]
# 3

# %% [markdown]
# Số lượng cluster khác nhau.

# %%
for K in [2, 5, 10, 15, 20]:
    kmeans = KMeans(n_clusters=K).fit(X)
    label = kmeans.predict(X)

    img4 = np.zeros_like(X)
    # replace each pixel by its center
    for k in range(K):
        img4[label == k] = kmeans.cluster_centers_[k]
    # reshape and display output image
    img5 = img4.reshape((img.shape[0], img.shape[1], img.shape[2]))
    plt.imshow(img5, interpolation='nearest')
    plt.axis('on')
    plt.show()
# Out:
# 800
# 800
# 800
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-ba28d0854abe> in <module>
#       1 for K in [2, 5, 10, 15, 20]:
# ----> 2     kmeans = KMeans(n_clusters=K).fit(X)
#       3     label = kmeans.predict(X)
#       4
#       5     img4 = np.zeros_like(X)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\cluster\_kmeans.py in fit(self, X, y, sample_weight)
#     935                     max_iter=self.max_iter, init=init, verbose=self.verbose,
#     936                     precompute_distances=precompute_distances, tol=tol,
# --> 937                     x_squared_norms=x_squared_norms, random_state=seed)
#     938                 # determine if these results are the best so far
#     939                 if best_inertia is None or inertia < best_inertia:
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\cluster\_kmeans.py in _kmeans_single_elkan(X, sample_weight, n_clusters, max_iter, init, verbose, x_squared_norms, random_state, tol, precompute_distances)
#     312     # init
#     313     centers = _init_centroids(X, n_clusters, init, random_state=random_state,
# --> 314                               x_squared_norms=x_squared_norms)
#     315     centers = np.ascontiguousarray(centers)
#     316     if verbose:
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\cluster\_kmeans.py in _init_centroids(X, k, init, random_state, x_squared_norms, init_size)
#     624     if isinstance(init, str) and init == 'k-means++':
#     625         centers = _k_init(X, k, random_state=random_state,
# --> 626                           x_squared_norms=x_squared_norms)
#     627     elif isinstance(init, str) and init == 'random':
#     628         seeds = random_state.permutation(n_samples)[:k]
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\cluster\_kmeans.py in _k_init(X, n_clusters, x_squared_norms, random_state, n_local_trials)
#     118         # update closest distances squared and potential for each candidate
#     119         np.minimum(closest_dist_sq, distance_to_candidates,
# --> 120                    out=distance_to_candidates)
#     121         candidates_pot = distance_to_candidates.sum(axis=1)
#     122
#
# KeyboardInterrupt:

# %%
for K in [3]:
    kmeans = KMeans(n_clusters=K).fit(X)
    label = kmeans.predict(X)

    img4 = np.zeros_like(X)
    # replace each pixel by its center
    for k in range(K):
        img4[label == k] = kmeans.cluster_centers_[k]
    # reshape and display output image
    img5 = img4.reshape((img.shape[0], img.shape[1], img.shape[2]))
    plt.imshow(img5)
    plt.axis('off')
    plt.show()

# %%
# Out:
# 1.7
